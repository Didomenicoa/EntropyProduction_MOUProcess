# %% [markdown]
# ## Remember to use MOU conda environment

# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
 # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time (?)
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %% [markdown]
# # Model optimization

# %%
# data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N,dtype=bool)
regul_Sigma = 0.0
conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

min_val_EC = 0. # maximal value for EC
max_val_EC = 1. # maximal value for EC
min_val_Sigma = 0. # minimal value for Sigma

# arrays to store results
var_BOLD = np.zeros([n_sub,n_cond,N]) # empirical BOLD variance
J_mod = np.zeros([n_sub,n_cond,N,N]) # model Jacobian (EC)
Sigma_mod = np.zeros([n_sub,n_cond,N,N]) # model 
FC0_mod = np.zeros([n_sub,n_cond,N,N]) # model zero-lad FC
err_mod = np.zeros([n_sub,n_cond]) # model error
fit_mod = np.zeros([n_sub,n_cond]) # model goodness of fit (Pearson corr)

#0.008-0.09 Hz
#0.008 to 0.08 Hz

n_order = 3
TR = 2 # in seconds
Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01 / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')


# loop over subject and conditions
for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        # get time serie
        ts3=ts_all[0:68, :,i_sub,i_cond]
        filt_ts = spsg.filtfilt(b,a,ts3,axis=1)
        ts=stats.zscore(ts3, axis=1)       #mask_EC=mask_ECS
        
        # store empirical BOLD variance
        var_BOLD[i_sub,i_cond,:] = ts.var(axis=1)
            #mask_EC=mask_ECS
        FC0 = np.tensordot(ts[:,:-1], ts[:,:-1], axes=(1,1)) / 149
        FC0N=abs(FC0)/np.max(abs(FC0))
        
        lim_FC0= np.percentile(FC0N, 70)

        # anatomy-derived mask for existing connections for EC
        mask_EC1 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC1[FC0N>lim_FC0] = True
        for i in range(N):
            mask_EC1[i,i] = True # no self connection
            
        mask_EC = np.zeros([N,N],dtype=bool)
    
        #types of MASKS: 
        mask_EC=mask_EC1 
        
        # invert model
        mou_est = MOUv2()
        mou_est.fit(ts.T, mask_C=mask_EC, mask_Sigma=mask_Sigma, algo_version='true', min_iter=100, epsilon_C=0.005, epsilon_Sigma=0.005) #, verbose=True)

        # store results
        J_mod[i_sub,i_cond,:,:] = mou_est.J
        Sigma_mod[i_sub,i_cond,:,:] = mou_est.Sigma
        FC0_mod[i_sub,i_cond,:,:] = spl.solve_lyapunov(J_mod[i_sub,i_cond,:,:].T, -Sigma_mod[i_sub,i_cond,:,:])
        err_mod[i_sub,i_cond] = mou_est.d_fit['distance']
        fit_mod[i_sub,i_cond] = mou_est.d_fit['correlation']

        print('sub', i_sub, '; cond', i_cond, ':', mou_est.d_fit)

#%% save results
np.save(res_dir+'J_mod.npy',J_mod)
np.save(res_dir+'Sigma_mod.npy',Sigma_mod)
np.save(res_dir+'FC0_mod.npy',FC0_mod)

np.save(res_dir+'err_mod.npy',err_mod)
np.save(res_dir+'fit_mod.npy',fit_mod)

np.save(res_dir+'var_BOLD.npy',var_BOLD)
# Out:
# sub 0 ; cond 0 : {'n_tau': 2, 'iterations': 115, 'distance': np.float64(0.8135047465385541), 'correlation': np.float64(0.6214308759747607), 'distance history': array([0.91124857, 0.90976858, 0.90830737, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38559493, 0.39006185, 0.39446477, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7714408135272603), 'distFC1': np.float64(0.8556536541910238)}
# sub 0 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8570673277972392), 'correlation': np.float64(0.5798569610884972), 'distance history': array([0.91644941, 0.91293448, 0.90987062, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37261965, 0.39888462, 0.42224516, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(3.5961182840794077), 'distFC1': np.float64(68.94547862611125)}
# sub 1 ; cond 0 : {'n_tau': 2, 'iterations': 122, 'distance': np.float64(0.8412937154782556), 'correlation': np.float64(0.5862159027610286), 'distance history': array([0.92786437, 0.92667586, 0.92549954, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35744719, 0.36086972, 0.3642522 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8127419771256787), 'distFC1': np.float64(0.8698605360171745)}
# sub 1 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.7942970141731678), 'correlation': np.float64(0.5615522703218025), 'distance history': array([0.92529747, 0.92096235, 0.91734396, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33767279, 0.37026146, 0.3978929 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(18.395205839966305), 'distFC1': np.float64(182.60980320621414)}
# sub 2 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8251614701230061), 'correlation': np.float64(0.6369161703168971), 'distance history': array([0.92278903, 0.92087423, 0.91901083, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36508626, 0.37377934, 0.38221972, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7739397040646356), 'distFC1': np.float64(0.9026848923223898)}
# sub 2 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8202676484022458), 'correlation': np.float64(0.6440960338678896), 'distance history': array([0.92576668, 0.92353154, 0.92137514, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36866451, 0.37972796, 0.39036222, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.786461213145364), 'distFC1': np.float64(0.9089995347636571)}
# sub 3 ; cond 0 : {'n_tau': 2, 'iterations': 119, 'distance': np.float64(0.8025626350472901), 'correlation': np.float64(0.6071582083977891), 'distance history': array([0.91044425, 0.9091142 , 0.9077982 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38546301, 0.38884851, 0.39219006, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7659495854810617), 'distFC1': np.float64(0.8392558889130658)}
# sub 3 ; cond 1 : {'n_tau': 2, 'iterations': 113, 'distance': np.float64(0.8309601793708448), 'correlation': np.float64(0.6069715761217419), 'distance history': array([0.92163889, 0.92024   , 0.9188593 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37318216, 0.37769044, 0.38212186, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8010619673963671), 'distFC1': np.float64(0.8608996597583135)}
# sub 4 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.
..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7846119264245195), 'distFC1': np.float64(0.8006868257888204)}
# sub 40 ; cond 0 : {'n_tau': 2, 'iterations': 129, 'distance': np.float64(0.8179198383317783), 'correlation': np.float64(0.6253332464567312), 'distance history': array([0.92683057, 0.92544135, 0.92406643, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35979015, 0.36377398, 0.36770807, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7918342059230474), 'distFC1': np.float64(0.8440180831959204)}
# sub 40 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8148804890116763), 'correlation': np.float64(0.6414482903781749), 'distance history': array([0.91179947, 0.90992391, 0.90809488, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39187449, 0.39969368, 0.40729665, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7509271032357522), 'distFC1': np.float64(0.8839263028457919)}
# sub 41 ; cond 0 : {'n_tau': 2, 'iterations': 123, 'distance': np.float64(0.8006085311474387), 'correlation': np.float64(0.6706553943123279), 'distance history': array([0.91102918, 0.90943754, 0.9078651 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.40077105, 0.40567798, 0.41050525, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7589756854112533), 'distFC1': np.float64(0.8422839701991539)}
# sub 41 ; cond 1 : {'n_tau': 2, 'iterations': 143, 'distance': np.float64(0.8223119181699698), 'correlation': np.float64(0.6191651241923999), 'distance history': array([0.94891473, 0.94727501, 0.94566757, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30796808, 0.31417499, 0.32023543, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8196776807626583), 'distFC1': np.float64(0.8249713643460234)}
# sub 42 ; cond 0 : {'n_tau': 2, 'iterations': 108, 'distance': np.float64(0.8006317642630697), 'correlation': np.float64(0.6722651305155236), 'distance history': array([0.92187623, 0.91994248, 0.91804577, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37639177, 0.38385219, 0.3911318 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7538811415375232), 'distFC1': np.float64(0.8474291677197137)}
# sub 42 ; cond 1 : {'n_tau': 2, 'iterations': 108, 'distance': np.float64(0.8517057704272384), 'correlation': np.float64(0.6195625109449929), 'distance history': array([0.94993762, 0.94825335, 0.94661361, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30041403, 0.30922671, 0.31778932, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8217898614096242), 'distFC1': np.float64(0.881750844223571)}
# sub 43 ; cond 0 : {'n_tau': 2, 'iterations': 134, 'distance': np.float64(0.8094267188630104), 'correlation': np.float64(0.6474601852809831), 'distance history': array([0.91617951, 0.91487472, 0.91358197, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38662318, 0.39024113, 0.39381813, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7741828678667314), 'distFC1': np.float64(0.8447042064147359)}
# sub 43 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8259652784470776), 'correlation': np.float64(0.6037846347254874), 'distance history': array([0.91984558, 0.91782173, 0.91586447, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36463587, 0.37401111, 0.38305943, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8259819433960909), 'distFC1': np.float64(0.9902062684600762)}
# sub 44 ; cond 0 : {'n_tau': 2, 'iterations': 126, 'distance': np.float64(0.8139205846122319), 'correlation': np.float64(0.6280094893948308), 'distance history': array([0.92327678, 0.92196192, 0.92065898, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36788341, 0.37138773, 0.37485343, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7861217272572777), 'distFC1': np.float64(0.8417324668015813)}
# sub 44 ; cond 1 : {'n_tau': 2, 'iterations': 124, 'distance': np.float64(0.8538419407678413), 'correlation': np.float64(0.5723506788305721), 'distance history': array([0.94405317, 0.94279259, 0.94154631, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31929384, 0.32333433, 0.32732259, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8447668356332231), 'distFC1': np.float64(0.8629694668204502)}
# sub 45 ; cond 0 : {'n_tau': 2, 'iterations': 114, 'distance': np.float64(0.8355575787512395), 'correlation': np.float64(0.6021729116559649), 'distance history': array([0.93132534, 0.92993197, 0.9285534 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3523561 , 0.3566722 , 0.36093188, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.811112264330899), 'distFC1': np.float64(0.8600589619644866)}
# sub 45 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8161879948395074), 'correlation': np.float64(0.6640577036980142), 'distance history': array([0.91994585, 0.91794604, 0.91599521, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37743216, 0.38593838, 0.39420863, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7599520217992282), 'distFC1': np.float64(0.8738804232972942)}
# sub 46 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8490482757372213), 'correlation': np.float64(0.5847472562573948), 'distance history': array([0.92833045, 0.92690966, 0.92551083, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35671668, 0.36216939, 0.36752039, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8074947370854284), 'distFC1': np.float64(0.891231305334731)}
# sub 46 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8943150581852216), 'correlation': np.float64(0.47027087649417126), 'distance history': array([0.94520069, 0.94418199, 0.94317833, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30901393, 0.31276771, 0.31646175, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8776659750747207), 'distFC1': np.float64(0.9305957215758055)}

# %%
plt.imshow(mask_EC1)

# %% [markdown]
# ## Check goodness of fit :

# %%
mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
n_cond=2

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

# model error #err_mod

err_mod_tmp = dict()
err_mod_tmp['sum EC'] = err_mod.flatten()
err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

err_mod_df = pd.DataFrame(err_mod_tmp)

plt.figure()
sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model error',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_fit_error.eps', format='eps')


# Pearson corr #fit_mod

fit_mod_tmp = dict()
fit_mod_tmp['sum EC'] = fit_mod.flatten()
fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

fit_mod_df = pd.DataFrame(fit_mod_tmp)

plt.figure()
sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model goodness of fit',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')


# Example EC

plt.figure(figsize=(5,4))
#plt.imshow(np.maximum(J_mod[18,1,:,:],0), cmap='Reds')
plt.imshow(J_mod[18,1,:,:], cmap='Reds')
plt.colorbar()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Target ROI index', fontsize=16)
plt.ylabel('Source ROI index', fontsize=16)
plt.tight_layout()
plt.savefig(res_dir+'example_EC.eps', format='eps')
# Out:
# /tmp/ipykernel_77646/4027539692.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_77646/4027539692.py:16: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_77646/4027539692.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_77646/4027539692.py:39: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)

# %% [markdown]
# ## ENTROPY CALCULATION

# %%
# transpose to Saclay's framework
EPR = np.zeros([n_sub,n_cond])
Q_indiv = np.zeros([n_sub,n_cond,N,N])

for i_sub in range(n_sub):
    for i_cond in range(n_cond):

        try:
            B = np.copy(-J_mod[i_sub,i_cond,:,:].T)
            D = np.copy(0.5 * Sigma_mod[i_sub,i_cond,:,:])
            S = np.copy(FC0_mod[i_sub,i_cond,:,:])
            
            Q = np.dot(B, S) - D
            Q_indiv[i_sub,i_cond,:,:] = Q
            
            # sanity check
            if True:
                print('should be close to zero:', np.abs(np.dot(B,S) + np.dot(S,B.T) -2*D).max())
            
            # formula from Godreche Luck
            Dinv = np.linalg.pinv(D)
            Sinv = np.linalg.pinv(S)
            
            entropy_prod_rate = -np.trace(np.dot(np.dot(np.dot(Sinv, Q), Dinv), Q))
            EPR[i_sub,i_cond] = entropy_prod_rate

        except:
            print('problem with subject/cond:', i_sub, i_cond)
# Out:
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 3.197442310920451e-14
# should be close to zero: 6.439293542825908e-15
# should be close to zero: 3.019806626980426e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 9.103828801926284e-15
# should be close to zero: 7.771561172376096e-15
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 5.10702591327572e-15
# should be close to zero: 3.375077994860476e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 1.7319479184152442e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 0.0
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 2.4868995751603507e-14
# should be close to zero: 9.103828801926284e-15
# should be close to zero: 1.3766765505351941e-14
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 1.509903313490213e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 3.375077994860476e-14
# should be close to zero: 7.105427357601002e-15
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 6.910270966553611e-15
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 9.119874994079069e-15
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 5.9119376061289586e-15
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 1.7319479184152442e-14
# should be close to zero: 3.552713678800501e-14
# should be close to zero: 1.0880185641326534e-14
# should be close to zero: 2.930988785010413e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 4.618527782440651e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 1.7763568394002505e-14
# should be close to zero: 3.552713678800501e-15
# should be close to zero: 1.7763568394002505e-14
# should be close to zero: 2.353672812205332e-14
# should be close to zero: 7.993605777301127e-15
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 6.8833827526759706e-15
# should be close to zero: 2.220446049250313e-14
# should be close to zero: 1.6431300764452317e-14
# should be close to zero: 1.865174681370263e-14
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 5.2111093218343285e-15
# should be close to zero: 3.4638958368304884e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.3766765505351941e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 3.375077994860476e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 2.2870594307278225e-14
# should be close to zero: 6.217248937900877e-15
# should be close to zero: 2.398081733190338e-14
# should be close to zero: 1.554312234475219e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 8.659739592076221e-15
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 1.6431300764452317e-14
# should be close to zero: 1.199040866595169e-14

# %%
#%% plots

matplotlib.rc('font', size=12) 
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]]
cols2 = [[0.7,0.7,1],[0.6,0.6,1],[0.5,0.5,1],[0.4,0.4,1]]

EPR_tmp = dict()
EPR_tmp['sleep stage'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()
EPR_tmp['EPR'] = EPR.flatten()

EPR_df = pd.DataFrame(EPR_tmp)


# real data

plt.figure()
ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
sb.swarmplot(data=EPR_df, x='sleep stage', y='EPR', color=[0.7,0.7,0.7])
plt.axis(ymin=0, ymax=5)

plt.xlabel('Condition', fontsize=12)
plt.ylabel('Entropy production rate', fontsize=12)

plt.savefig(res_dir+'entropy_prod_rate.eps', format='eps')
# Out:
# /tmp/ipykernel_77646/2923277758.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
# /tmp/ipykernel_77646/2923277758.py:20: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)

# %%
EPR_df
# Out:
#    sleep stage       EPR
# 0          CTR  1.142755
# 1          SCZ  1.681013
# 2          CTR  0.781449
# 3          SCZ  3.052145
# 4          CTR  1.615933
# ..         ...       ...
# 89         SCZ  0.632800
# 90         CTR  0.562228
# 91         SCZ  0.993688
# 92         CTR  1.070475
# 93         SCZ  0.944314
#
# [94 rows x 2 columns]

# %% [markdown]
# Verify that the two groups are
# ## Statistically Different

# %% [markdown]
# 3. Check if the two groups are statistically different: WELCH TEST

# %%
CTR = EPR[:,0]
SCZ = EPR[:,1]
stat_t, p_t = stats.ttest_ind(CTR, SCZ, equal_var=False)

print(f"Welch's t-test statistic: {stat_t:.3f}, p-value: {p_t:.3f}")

if p_t < 0.05:
    print("The difference between groups is statistically significant.")
else:
    print("No significant difference between groups.")
# Out:
# Welch's t-test statistic: -3.850, p-value: 0.000
# The difference between groups is statistically significant.
