# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
 # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time (?)
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %%
# data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N,dtype=bool)
regul_Sigma = 0.0
conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

min_val_EC = 0. # maximal value for EC
max_val_EC = 1. # maximal value for EC
min_val_Sigma = 0. # minimal value for Sigma

# arrays to store results
var_BOLD = np.zeros([n_sub,n_cond,N]) # empirical BOLD variance
J_mod = np.zeros([n_sub,n_cond,N,N]) # model Jacobian (EC)
Sigma_mod = np.zeros([n_sub,n_cond,N,N]) # model 
FC0_mod = np.zeros([n_sub,n_cond,N,N]) # model zero-lad FC
err_mod = np.zeros([n_sub,n_cond]) # model error
fit_mod = np.zeros([n_sub,n_cond]) # model goodness of fit (Pearson corr)

#0.008-0.09 Hz
#0.008 to 0.08 Hz

n_order = 3
TR = 2 # in seconds
Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01 / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')


# loop over subject and conditions
for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        # get time serie
        ts3=ts_all[0:68, :,i_sub,i_cond]
        filt_ts = spsg.filtfilt(b,a,ts3,axis=1)
        ts=stats.zscore(ts3, axis=1)       #mask_EC=mask_ECS
        
        # store empirical BOLD variance
        var_BOLD[i_sub,i_cond,:] = ts.var(axis=1)
            #mask_EC=mask_ECS
        FC0 = np.tensordot(ts[:,:-1], ts[:,:-1], axes=(1,1)) / 149
        FC1 = np.tensordot(ts[:,:-1], ts[:,1:], axes=(1,1)) / 149
        FC0N=abs(FC0)/np.max(abs(FC0))
        FC1N=abs(FC1)/np.max(abs(FC1))
        
        lim_FC0= np.percentile(FC0N, 60)
        lim_FC1= np.percentile(FC1N, 50)

        # anatomy-derived mask for existing connections for EC
        mask_EC1 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC1[FC0N>lim_FC0] = True
        for i in range(N):
            mask_EC1[i,i] = True # no self connection
            
        
        mask_EC2 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC2[abs(FC1N)>lim_FC1] = True
        for i in range(N):
            mask_EC2[i,i] = False # no self connection
            
        mask_EC = np.zeros([N,N],dtype=bool)
    
        #types of MASKS: 
        mask_EC= np.logical_or(mask_EC1, mask_EC2).astype(int)
        
        # invert model
        mou_est = MOUv2()
        mou_est.fit(ts.T, mask_C=mask_EC, mask_Sigma=mask_Sigma, algo_version='true', min_iter=100, epsilon_C=0.005, epsilon_Sigma=0.005) #, verbose=True)

        # store results
        J_mod[i_sub,i_cond,:,:] = mou_est.J
        Sigma_mod[i_sub,i_cond,:,:] = mou_est.Sigma
        FC0_mod[i_sub,i_cond,:,:] = spl.solve_lyapunov(J_mod[i_sub,i_cond,:,:].T, -Sigma_mod[i_sub,i_cond,:,:])
        err_mod[i_sub,i_cond] = mou_est.d_fit['distance']
        fit_mod[i_sub,i_cond] = mou_est.d_fit['correlation']

        print('sub', i_sub, '; cond', i_cond, ':', mou_est.d_fit)

#%% save results
np.save(res_dir+'J_mod.npy',J_mod)
np.save(res_dir+'Sigma_mod.npy',Sigma_mod)
np.save(res_dir+'FC0_mod.npy',FC0_mod)

np.save(res_dir+'err_mod.npy',err_mod)
np.save(res_dir+'fit_mod.npy',fit_mod)

np.save(res_dir+'var_BOLD.npy',var_BOLD)
# Out:
# sub 0 ; cond 0 : {'n_tau': 2, 'iterations': 286, 'distance': np.float64(0.9064396861733162), 'correlation': np.float64(0.3986821805921741), 'distance history': array([0.91124857, 0.91121505, 0.91118144, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38559493, 0.38569983, 0.38580486, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8522720177204998), 'distFC1': np.float64(0.9606075744257072)}
# sub 0 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.911440590335024), 'correlation': np.float64(0.3966745740247317), 'distance history': array([0.91644941, 0.9163371 , 0.91622443, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37261965, 0.37358775, 0.37455195, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8339583703361704), 'distFC1': np.float64(0.9896289010040223)}
# sub 1 ; cond 0 : {'n_tau': 2, 'iterations': 411, 'distance': np.float64(0.9181955857005607), 'correlation': np.float64(0.38462404079465995), 'distance history': array([0.92786437, 0.92781321, 0.92776189, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35744719, 0.3575974 , 0.35774802, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8841061184918849), 'distFC1': np.float64(0.9522850949387998)}
# sub 1 ; cond 1 : {'n_tau': 2, 'iterations': 246, 'distance': np.float64(0.9127068852941491), 'correlation': np.float64(0.2883416895479164), 'distance history': array([0.92529747, 0.92522396, 0.92514016, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33767279, 0.33886608, 0.34002803, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8380063379128188), 'distFC1': np.float64(0.9874088629414255)}
# sub 2 ; cond 0 : {'n_tau': 2, 'iterations': 157, 'distance': np.float64(0.919082383758778), 'correlation': np.float64(0.3785837478406784), 'distance history': array([0.92278903, 0.92275801, 0.92272687, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36508626, 0.36526085, 0.36543505, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8618250404432712), 'distFC1': np.float64(0.9763407050466433)}
# sub 2 ; cond 1 : {'n_tau': 2, 'iterations': 257, 'distance': np.float64(0.9208071804765829), 'correlation': np.float64(0.37537478826813264), 'distance history': array([0.92576668, 0.92572538, 0.92568401, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36866451, 0.36888331, 0.36910082, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8648275293102734), 'distFC1': np.float64(0.9767869609958231)}
# sub 3 ; cond 0 : {'n_tau': 2, 'iterations': 232, 'distance': np.float64(0.908104153025088), 'correlation': np.float64(0.3875860428964091), 'distance history': array([0.91044425, 0.91042852, 0.91041279, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38546301, 0.38550132, 0.38553949, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8612822843116335), 'distFC1': np.float64(0.954926264832714)}
# sub 3 ; cond 1 : {'n_tau': 2, 'iterations': 321, 'distance': np.float64(0.9171506798908529), 'correlation': np.float64(0.38271457504842976), 'distance history': array([0.92163889, 0.92160543, 0.92157201, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37318216, 0.37329467, 0.37340682, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8779844991032674), 'distFC1': np.float64(0.9563169294033591)}
# sub 4 ; cond 0 : {'n_tau': 2, 'iterations': 6772, 'distance': np.float64(0.9368108159617196), 'correlation': np.float64(0.3668207047047203), 'distance history': array([0.97302606, 0.97292631, 0.97282422, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.22235662, 0.22311263, 0.22388307, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9233149232105744), 'distFC1': np.float64(0.9503067087129189)}
# sub 4 ; cond 1 : {'n_tau': 2, 'iterations': 439, 'distance': np.float64(0.9019293414917391), 'correlation': np.float64(0.4159068843264867), 'distance history': array([0.91466401, 0.91460422, 0.9145444 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38455424, 0.38471962, 0.38488488, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8586054026772842), 'distFC1': np.float64(0.9452533279157569)}
# sub 5 ; cond 0 : {'n_tau': 2, 'iterations': 850, 'distance': np.float64(0.9226984694683937), 'correlation': np.float64(0.38429598858206016), 'distance history': array([0.93913396, 0.93904977, 0.93896509, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33369178, 0.33395966, 0.33422903, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8970088672310192), 'distFC1': np.float64(0.9483880979273945)}
# sub 5 ; cond 1 : {'n_tau': 2, 'iterations': 672, 'distance': np.float64(0.8833711302097671), 'correlation': np.float64(0.44970126523870535), 'distance history': array([0.9072987 , 0.90721268, 0.90712631, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39855279, 0.39878919, 0.39902617, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8301553069304568), 'distFC1': np.float64(0.9365869985713722)}
# sub 6 ; cond 0 : {'n_tau': 2, 'iterations': 159, 'distance': np.float64(0.9349275535862706), 'correlation': np.float64(0.3474225571447437), 'distance history': array([0.93712397, 0.93710494, 0.93708572, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34052594, 0.34061416, 0.34070264, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9056909346671193), 'distFC1': np.float64(0.9641643324772913)}
# sub 6 ; cond 1 : {'n_tau': 2, 'iterations': 433, 'distance': np.float64(0.922213975529504), 'correlation': np.float64(0.37483195855740603), 'distance history': array([0.92774293, 0.92771215, 0.92768115, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36274452, 0.36285625, 0.36296837, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8855662936789381), 'distFC1': np.float64(0.9588617560130747)}
# sub 7 ; cond 0 : {'n_tau': 2, 'iterations': 615, 'distance': np.float64(0.9138336909849618), 'correlation': np.float64(0.38440770806981894), 'distance history': array([0.92218653, 0.92213979, 0.92209294, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36061937, 0.3607637 , 0.36090835, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8662865440606222), 'distFC1': np.float64(0.9613808648650931)}
# sub 7 ; cond 1 : {'n_tau': 2, 'iterations': 356, 'distance': np.float64(0.9359434348863824), 'correlation': np.float64(0.33562013454499745), 'distance history': array([0.94240077, 0.94235772, 0.94231449, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31683674, 0.31699002, 0.31714387, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9042107556203197), 'distFC1': np.float64(0.9676762755951737)}
# sub 8 ; cond 0 : {'n_tau': 2, 'iterations': 383, 'distance': np.float64(0.913737329282969), 'correlation': np.float64(0.39177541472379657), 'distance history': array([0.92098727, 0.92095605, 0.92092467, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3757234 , 0.37580555, 0.37588794, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8826505543540237), 'distFC1': np.float64(0.9448242491395243)}
# sub 8 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8933549608132312), 'correlation': np.float64(0.40666207186752307), 'distance history': array([0.89655441, 0.89640353, 0.89625278, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38556293, 0.38712763, 0.38867501, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7961859496733243), 'distFC1': np.float64(0.9946789422926953)}
# sub 9 ; cond 0 : {'n_tau': 2, 'iterations': 330, 'distance': np.float64(0.9050417344582903), 'correlation': np.float64(0.39745987003279715), 'distance history': array([0.91563486, 0.91556075, 0.91548558, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36812487, 0.36848007, 0.36883784, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8389385339717454), 'distFC1': np.float64(0.9711449918601454)}
# sub 9 ; cond 1 : {'n_tau': 2, 'iterations': 335, 'distance': np.float64(0.9532303395396025), 'correlation': np.float64(0.28428007774927755), 'distance history': array([0.95682231, 0.95679909, 0.95677579, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.27578926, 0.27587841, 0.27596782, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9320550126064745), 'distFC1': np.float64(0.9744058576376565)}
# sub 10 ; cond 0 : {'n_tau': 2, 'iterations': 447, 'distance': np.float64(0.89642181180911), 'correlation': np.float64(0.437260314148094), 'distance history': array([0.91639589, 0.91629404, 0.91619172, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38033351, 0.38064911, 0.3809658 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8521628555369358), 'distFC1': np.float64(0.9406811861895753)}
# sub 10 ; cond 1 : {'n_tau': 2, 'iterations': 301, 'distance': np.float64(0.9224486612754559), 'correlation': np.float64(0.3764714185033958), 'distance history': array([0.93087847, 0.93080512, 0.93073094, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34406863, 0.34438912, 0.34471245, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8745222182104532), 'distFC1': np.float64(0.9703753830870416)}
# sub 11 ; cond 0 : {'n_tau': 2, 'iterations': 377, 'distance': np.float64(0.9254772868087926), 'correlation': np.float64(0.36932411851764724), 'distance history': array([0.92954097, 0.92951741, 0.92949383, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35720482, 0.35729431, 0.3573837 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8860209222249268), 'distFC1': np.float64(0.9649337280036184)}
# sub 11 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9694101132287622), 'correlation': np.float64(0.20234387473325316), 'distance history': array([0.97052259, 0.97023771, 0.96998765, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.21387551, 0.22584541, 0.23031264, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9401084558483513), 'distFC1': np.float64(0.999654641698045)}
# sub 12 ; cond 0 : {'n_tau': 2, 'iterations': 516, 'distance': np.float64(0.9147343980434081), 'correlation': np.float64(0.3834240395193953), 'distance history': array([0.92510562, 0.92507244, 0.92503895, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35931972, 0.35942414, 0.35952923, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.870816826654028), 'distFC1': np.float64(0.9586519873016308)}
# sub 12 ; cond 1 : {'n_tau': 2, 'iterations': 155, 'distance': np.float64(0.9051455149850807), 'correlation': np.float64(0.3928945725711917), 'distance history': array([0.91273064, 0.91265387, 0.91257423, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37150045, 0.37224842, 0.37299564, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8220667834323152), 'distFC1': np.float64(0.9882249040889914)}
# sub 13 ; cond 0 : {'n_tau': 2, 'iterations': 1038, 'distance': np.float64(0.9291890412350123), 'correlation': np.float64(0.34354356656491913), 'distance history': array([0.95016628, 0.95009914, 0.9500312 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.2902577 , 0.29046089, 0.29066623, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8917896771207515), 'distFC1': np.float64(0.9665884246686477)}
# sub 13 ; cond 1 : {'n_tau': 2, 'iterations': 331, 'distance': np.float64(0.904362309844995), 'correlation': np.float64(0.39046059635370334), 'distance history': array([0.90963037, 0.90959076, 0.909551  , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37807936, 0.37820152, 0.37832389, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8438435101095866), 'distFC1': np.float64(0.9648812223664045)}
# sub 14 ; cond 0 : {'n_tau': 2, 'iterations': 150, 'distance': np.float64(0.9042669869278719), 'correlation': np.float64(0.40980504547854607), 'distance history': array([0.91330509, 0.91311006, 0.91291392, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38138719, 0.38310046, 0.38479354, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8181250407761438), 'distFC1': np.float64(0.9904102097743522)}
# sub 14 ; cond 1 : {'n_tau': 2, 'iterations': 331, 'distance': np.float64(0.9174916557132585), 'correlation': np.float64(0.36913298230991926), 'distance history': array([0.92431845, 0.92426613, 0.92421328, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35287104, 0.35312551, 0.35338141, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8584212197492652), 'distFC1': np.float64(0.9765621618942908)}
# sub 15 ; cond 0 : {'n_tau': 2, 'iterations': 465, 'distance': np.float64(0.9387716272853426), 'correlation': np.float64(0.3429273548985574), 'distance history': array([0.94521891, 0.94517992, 0.94514056, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.32099858, 0.32119271, 0.32138812, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9040771186706388), 'distFC1': np.float64(0.9734662203080088)}
# sub 15 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9204337335199204), 'correlation': np.float64(0.37184405935840326), 'distance history': array([0.92235288, 0.92227477, 0.92219663, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35310631, 0.35399497, 0.35487943, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.848938031541239), 'distFC1': np.float64(0.9933108901114002)}
# sub 16 ; cond 0 : {'n_tau': 2, 'iterations': 598, 'distance': np.float64(0.904105637678005), 'correlation': np.float64(0.41496104804435285), 'distance history': array([0.91443823, 0.91439815, 0.91435804, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39080206, 0.39090344, 0.39100483, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8708181235142756), 'distFC1': np.float64(0.9373932087798587)}
# sub 16 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.937848302139697), 'correlation': np.float64(0.36240535662541046), 'distance history': array([0.94189026, 0.94160615, 0.94134513, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.32548557, 0.33034502, 0.33484804, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8801457537331144), 'distFC1': np.float64(0.9961000919541512)}
# sub 17 ; cond 0 : {'n_tau': 2, 'iterations': 239, 'distance': np.float64(0.8952246430992532), 'correlation': np.float64(0.4202802980825735), 'distance history': array([0.89878636, 0.89876172, 0.89873693, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.41009045, 0.41016719, 0.41024423, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8322121808265103), 'distFC1': np.float64(0.9582372759909038)}
# sub 17 ; cond 1 : {'n_tau': 2, 'iterations': 201, 'distance': np.float64(0.9299972891428149), 'correlation': np.float64(0.3538901557355793), 'distance history': array([0.93166241, 0.93165011, 0.93163775, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35069966, 0.3507533 , 0.35080679, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8927827747180377), 'distFC1': np.float64(0.9672119724950443)}
# Optimization did not converge. Maximum number of iterations arrived.
# sub 18 ; cond 0 : {'n_tau': 2, 'iterations': 10000, 'distance': np.float64(0.90508082045973), 'correlation': np.float64(0.4299113642800438), 'distance history': array([0.94131903, 0.94123486, 0.94114939, ..., 0.90508082, 0.90508082,
#        0.90508082]), 'correlation history': array([0.3228696 , 0.32313891, 0.32341192, ..., 0.42991136, 0.42991136,
#        0.42991136]), 'distFC0': np.float64(0.8789157148110303), 'distFC1': np.float64(0.9312459261084297)}
# sub 18 ; cond 1 : {'n_tau': 2, 'iterations': 439, 'distance': np.float64(0.9080779038564964), 'correlation': np.float64(0.4118175154983781), 'distance history': array([0.9181712 , 0.91810686, 0.91804194, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38450648, 0.38477991, 0.38505453, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8528916225478448), 'distFC1': np.float64(0.9632642445718269)}
# sub 19 ; cond 0 : {'n_tau': 2, 'iterations': 416, 'distance': np.float64(0.9172976008138367), 'correlation': np.float64(0.3932214598150589), 'distance history': array([0.92903676, 0.92897336, 0.92890969, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35571761, 0.35592625, 0.35613564, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8811997111069979), 'distFC1': np.float64(0.953395582662681)}
# sub 19 ; cond 1 : {'n_tau': 2, 'iterations': 322, 'distance': np.float64(0.9271799406780432), 'correlation': np.float64(0.360599879282521), 'distance history': array([0.93815818, 0.93808318, 0.93800782, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.32835928, 0.32862014, 0.32888182, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8978549815694682), 'distFC1': np.float64(0.9565050278349212)}
# sub 20 ; cond 0 : {'n_tau': 2, 'iterations': 426, 'distance': np.float64(0.9080412310617407), 'correlation': np.float64(0.4092551276180789), 'distance history': array([0.92219195, 0.92213229, 0.92207215, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37443162, 0.37464814, 0.37486573, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8604833113708299), 'distFC1': np.float64(0.9555992965138917)}
# sub 20 ; cond 1 : {'n_tau': 2, 'iterations': 213, 'distance': np.float64(0.9036174442117231), 'correlation': np.float64(0.4064307600934751), 'distance history': array([0.90837602, 0.90833329, 0.90829059, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39658501, 0.39679987, 0.39701361, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.829341813154794), 'distFC1': np.float64(0.9778947823698908)}
# sub 21 ; cond 0 : {'n_tau': 2, 'iterations': 604, 'distance': np.float64(0.9145951630494564), 'correlation': np.float64(0.39968383960316545), 'distance history': array([0.9353504 , 0.93524499, 0.93513834, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33824757, 0.33859564, 0.33894747, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8821085456815256), 'distFC1': np.float64(0.947081878824711)}
# sub 21 ; cond 1 : {'n_tau': 2, 'iterations': 259, 'distance': np.float64(0.9300409784005544), 'correlation': np.float64(0.351333033460687), 'distance history': array([0.93960386, 0.93951442, 0.93942422, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33192963, 0.33261811, 0.33330176, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8748057168633292), 'distFC1': np.float64(0.9852768343025005)}
# sub 22 ; cond 0 : {'n_tau': 2, 'iterations': 284, 'distance': np.float64(0.9201186576903838), 'correlation': np.float64(0.375242404266947), 'distance history': array([0.92519895, 0.92516436, 0.92512966, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3634417 , 0.36354111, 0.36364071, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8872164411152905), 'distFC1': np.float64(0.9530212286510894)}
# sub 22 ; cond 1 : {'n_tau': 2, 'iterations': 568, 'distance': np.float64(0.9109908120863268), 'correlation': np.float64(0.3916080385270633), 'distance history': array([0.92536128, 0.92530208, 0.92524229, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35481382, 0.35500216, 0.35519191, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8674576802999403), 'distFC1': np.float64(0.9545240006123623)}
# sub 23 ; cond 0 : {'n_tau': 2, 'iterations': 280, 'distance': np.float64(0.90711849047768), 'correlation': np.float64(0.4129576870049528), 'distance history': array([0.91446534, 0.91440166, 0.9143378 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39034939, 0.39064663, 0.39094364, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8480103530689681), 'distFC1': np.float64(0.9662268593730715)}
# sub 23 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.896504383607753), 'correlation': np.float64(0.40429997145968083), 'distance history': array([0.89813096, 0.89801614, 0.89790391, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38757261, 0.3888557 , 0.39011481, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8043983110402396), 'distFC1': np.float64(0.9960480945112928)}
# sub 24 ; cond 0 : {'n_tau': 2, 'iterations': 549, 'distance': np.float64(0.9165234105446485), 'correlation': np.float64(0.3922143583403517), 'distance history': array([0.92715157, 0.92708782, 0.92702369, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3616536 , 0.36184584, 0.36203909, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8836678517499342), 'distFC1': np.float64(0.9493789824573848)}
# sub 24 ; cond 1 : {'n_tau': 2, 'iterations': 121, 'distance': np.float64(0.928242807197216), 'correlation': np.float64(0.375106482971814), 'distance history': array([0.93443553, 0.93428459, 0.93413069, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33027288, 0.33217665, 0.33408209, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8687382403711555), 'distFC1': np.float64(0.9877474038995084)}
# sub 25 ; cond 0 : {'n_tau': 2, 'iterations': 6703, 'distance': np.float64(0.9020844160410352), 'correlation': np.float64(0.3927328520039897), 'distance history': array([0.92091222, 0.92081963, 0.92072653, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36728622, 0.36772852, 0.3681704 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8368480077788667), 'distFC1': np.float64(0.9673208243032045)}
# sub 25 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9129185405499582), 'correlation': np.float64(0.36788835527590036), 'distance history': array([0.9148315 , 0.9144786 , 0.91419781, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34865362, 0.35511712, 0.3603094 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8283593022897491), 'distFC1': np.float64(0.9988004892889623)}
# sub 26 ; cond 0 : {'n_tau': 2, 'iterations': 377, 'distance': np.float64(0.9220582621524557), 'correlation': np.float64(0.3624269503658548), 'distance history': array([0.93647571, 0.93639505, 0.9363135 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33245846, 0.33272546, 0.3329945 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8915887361271699), 'distFC1': np.float64(0.9525277956320926)}
# sub 26 ; cond 1 : {'n_tau': 2, 'iterations': 256, 'distance': np.float64(0.9242756940400602), 'correlation': np.float64(0.3661205157568781), 'distance history': array([0.9279844 , 0.92795703, 0.92792962, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35784143, 0.35794063, 0.35803967, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8843928611184195), 'distFC1': np.float64(0.9641587077847316)}
# sub 27 ; cond 0 : {'n_tau': 2, 'iterations': 211, 'distance': np.float64(0.9073975477908613), 'correlation': np.float64(0.4009612147436399), 'distance history': array([0.91227648, 0.91223052, 0.91218446, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38672236, 0.38694513, 0.38716729, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8440331577015617), 'distFC1': np.float64(0.9707623057370798)}
# sub 27 ; cond 1 : {'n_tau': 2, 'iterations': 292, 'distance': np.float64(0.9059397010783344), 'correlation': np.float64(0.3901177340547688), 'distance history': array([0.91033799, 0.91029045, 0.91024274, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38665793, 0.38695737, 0.3872544 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8280680560069044), 'distFC1': np.float64(0.9838113634906601)}
# sub 28 ; cond 0 : {'n_tau': 2, 'iterations': 442, 'distance': np.float64(0.9193854372052398), 'correlation': np.float64(0.38593933265745883), 'distance history': array([0.9311486 , 0.93110445, 0.93106001, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35532763, 0.3554483 , 0.35556965, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8982043763190463), 'distFC1': np.float64(0.940566815577833)}
# sub 28 ; cond 1 : {'n_tau': 2, 'iterations': 287, 'distance': np.float64(0.9178197786929747), 'correlation': np.float64(0.40184729119446655), 'distance history': array([0.92860815, 0.92850984, 0.92841127, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3649503 , 0.36546388, 0.36597667, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8658104397921128), 'distFC1': np.float64(0.9698341991245617)}
# sub 29 ; cond 0 : {'n_tau': 2, 'iterations': 277, 'distance': np.float64(0.916480598126425), 'correlation': np.float64(0.3801226820117023), 'distance history': array([0.92069389, 0.92066898, 0.9206439 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37293049, 0.37304213, 0.37315361, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8613438128513972), 'distFC1': np.float64(0.9716174720354546)}
# sub 29 ; cond 1 : {'n_tau': 2, 'iterations': 278, 'distance': np.float64(0.918638013950949), 'correlation': np.float64(0.3773556248087277), 'distance history': array([0.92219494, 0.92217703, 0.92215909, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37014444, 0.37019991, 0.3702553 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8809971385763106), 'distFC1': np.float64(0.9562790009397508)}
# sub 30 ; cond 0 : {'n_tau': 2, 'iterations': 312, 'distance': np.float64(0.9269857338709064), 'correlation': np.float64(0.3720638534842421), 'distance history': array([0.93080355, 0.93076716, 0.93073067, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35878407, 0.35895265, 0.3591213 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8823480233709524), 'distFC1': np.float64(0.9716234781280529)}
# sub 30 ; cond 1 : {'n_tau': 2, 'iterations': 621, 'distance': np.float64(0.9119167393070373), 'correlation': np.float64(0.3912824962359961), 'distance history': array([0.91969911, 0.91966337, 0.91962736, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37426086, 0.37436111, 0.37446195, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8736268641712823), 'distFC1': np.float64(0.9502066319155769)}
# sub 31 ; cond 0 : {'n_tau': 2, 'iterations': 159, 'distance': np.float64(0.9215461331514734), 'correlation': np.float64(0.36981243852780343), 'distance history': array([0.92497947, 0.92493334, 0.92488728, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36010787, 0.36042828, 0.36074572, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8567321931479057), 'distFC1': np.float64(0.9863601124779424)}
# sub 31 ; cond 1 : {'n_tau': 2, 'iterations': 275, 'distance': np.float64(0.9149624760283326), 'correlation': np.float64(0.38979178652120233), 'distance history': array([0.9242142 , 0.92415251, 0.92408998, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36066666, 0.36094117, 0.36121812, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8637158735660158), 'distFC1': np.float64(0.9662097578818761)}
# sub 32 ; cond 0 : {'n_tau': 2, 'iterations': 123, 'distance': np.float64(0.910352084837948), 'correlation': np.float64(0.38795707610376406), 'distance history': array([0.91260008, 0.91256252, 0.91252484, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38179158, 0.38204013, 0.38228664, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8344959934139696), 'distFC1': np.float64(0.986208397821252)}
# sub 32 ; cond 1 : {'n_tau': 2, 'iterations': 173, 'distance': np.float64(0.919210194082624), 'correlation': np.float64(0.3790898267175585), 'distance history': array([0.92587331, 0.92579239, 0.92571163, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35930154, 0.35982589, 0.36034806, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.854436380300819), 'distFC1': np.float64(0.9839868421033322)}
# sub 33 ; cond 0 : {'n_tau': 2, 'iterations': 620, 'distance': np.float64(0.9028012653318346), 'correlation': np.float64(0.4114546149337199), 'distance history': array([0.91073468, 0.91069682, 0.9106589 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39529543, 0.39541675, 0.39553792, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.851773156981214), 'distFC1': np.float64(0.9538293758888227)}
# sub 33 ; cond 1 : {'n_tau': 2, 'iterations': 352, 'distance': np.float64(0.929615258729156), 'correlation': np.float64(0.27251243630609506), 'distance history': array([0.94680318, 0.94673262, 0.94666089, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.29975659, 0.30029314, 0.30082713, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8651140813543428), 'distFC1': np.float64(0.9941196640159752)}
# sub 34 ; cond 0 : {'n_tau': 2, 'iterations': 235, 'distance': np.float64(0.9232610054531724), 'correlation': np.float64(0.3665924692172991), 'distance history': array([0.92570226, 0.92568026, 0.92565823, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35640215, 0.3565027 , 0.35660315, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8709414075682722), 'distFC1': np.float64(0.9755807134734248)}
# sub 34 ; cond 1 : {'n_tau': 2, 'iterations': 179, 'distance': np.float64(0.9262165049269202), 'correlation': np.float64(0.3614660471115553), 'distance history': array([0.9290633 , 0.92903612, 0.92900888, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35224599, 0.35237451, 0.35250269, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8813769414525002), 'distFC1': np.float64(0.971056087226819)}
# sub 35 ; cond 0 : {'n_tau': 2, 'iterations': 500, 'distance': np.float64(0.9277924145145052), 'correlation': np.float64(0.3568609375456805), 'distance history': array([0.93591906, 0.93587091, 0.93582229, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3366862 , 0.33683018, 0.33697537, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9026049936614288), 'distFC1': np.float64(0.9529798394435568)}
# sub 35 ; cond 1 : {'n_tau': 2, 'iterations': 124, 'distance': np.float64(0.9121542532170268), 'correlation': np.float64(0.4001608490187788), 'distance history': array([0.92085509, 0.92063688, 0.9204199 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36417117, 0.36676177, 0.36931609, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8356309990263553), 'distFC1': np.float64(0.9886784912360229)}
# sub 36 ; cond 0 : {'n_tau': 2, 'iterations': 341, 'distance': np.float64(0.9050923891831446), 'correlation': np.float64(0.418321405395784), 'distance history': array([0.91480047, 0.9147544 , 0.91470828, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38734071, 0.3874862 , 0.38763175, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.861941135754634), 'distFC1': np.float64(0.9482437649318309)}
# sub 36 ; cond 1 : {'n_tau': 2, 'iterations': 235, 'distance': np.float64(0.9202022568980235), 'correlation': np.float64(0.37509311995557315), 'distance history': array([0.9292016 , 0.92911455, 0.92902717, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34451046, 0.34488914, 0.34526869, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8730653048004058), 'distFC1': np.float64(0.9673398076128407)}
# sub 37 ; cond 0 : {'n_tau': 2, 'iterations': 178, 'distance': np.float64(0.9126980751994687), 'correlation': np.float64(0.3845960903362431), 'distance history': array([0.91701857, 0.91697484, 0.91693086, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36867932, 0.36888637, 0.36909363, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8517017879442216), 'distFC1': np.float64(0.9736946907564775)}
# sub 37 ; cond 1 : {'n_tau': 2, 'iterations': 301, 'distance': np.float64(0.9281092601802083), 'correlation': np.float64(0.3566305489473031), 'distance history': array([0.93369434, 0.93362626, 0.93355707, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34111575, 0.34162738, 0.34214152, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8708786326679415), 'distFC1': np.float64(0.9853399108054223)}
# sub 38 ; cond 0 : {'n_tau': 2, 'iterations': 760, 'distance': np.float64(0.900056506435462), 'correlation': np.float64(0.4333643350582229), 'distance history': array([0.91694307, 0.91682814, 0.91671286, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39068622, 0.39125058, 0.39181463, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8374360159563462), 'distFC1': np.float64(0.9626805899014121)}
# sub 38 ; cond 1 : {'n_tau': 2, 'iterations': 128, 'distance': np.float64(0.8919940141147749), 'correlation': np.float64(0.41352573346539173), 'distance history': array([0.89511588, 0.89506497, 0.89501385, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.40007016, 0.40046983, 0.40086727, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7957080405441571), 'distFC1': np.float64(0.9882804783800079)}
# sub 39 ; cond 0 : {'n_tau': 2, 'iterations': 312, 'distance': np.float64(0.9352599618885472), 'correlation': np.float64(0.3482169267525474), 'distance history': array([0.94059498, 0.94055875, 0.94052252, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33479117, 0.3349651 , 0.33513847, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8973120563734001), 'distFC1': np.float64(0.9732081299478498)}
# sub 39 ; cond 1 : {'n_tau': 2, 'iterations': 300, 'distance': np.float64(0.9300842794554219), 'correlation': np.float64(0.32421149223395196), 'distance history': array([0.93692856, 0.9368918 , 0.93685454, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.32159203, 0.32168831, 0.32178568, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9015480574622652), 'distFC1': np.float64(0.9586207648982324)}
# sub 40 ; cond 0 : {'n_tau': 2, 'iterations': 444, 'distance': np.float64(0.9184562304417655), 'correlation': np.float64(0.38083091468507657), 'distance history': array([0.92683057, 0.92679067, 0.92675071, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35979015, 0.35990434, 0.3600186 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8846121127768213), 'distFC1': np.float64(0.95230044294044)}
# sub 40 ; cond 1 : {'n_tau': 2, 'iterations': 221, 'distance': np.float64(0.9030202230792872), 'correlation': np.float64(0.42330388023606585), 'distance history': array([0.91179947, 0.91172128, 0.91164264, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39187449, 0.39223284, 0.39259243, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8374349228291315), 'distFC1': np.float64(0.9686058209299547)}
# sub 41 ; cond 0 : {'n_tau': 2, 'iterations': 367, 'distance': np.float64(0.9037081568540517), 'correlation': np.float64(0.41926732682170736), 'distance history': array([0.91102918, 0.9109891 , 0.910949  , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.40077105, 0.40090065, 0.40103008, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8560616398696212), 'distFC1': np.float64(0.9513548493320206)}
# sub 41 ; cond 1 : {'n_tau': 2, 'iterations': 503, 'distance': np.float64(0.9411379710117433), 'correlation': np.float64(0.32344031264537176), 'distance history': array([0.94891473, 0.94886495, 0.94881472, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30796808, 0.30815882, 0.3083506 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9242017230492258), 'distFC1': np.float64(0.9580742441273286)}
# sub 42 ; cond 0 : {'n_tau': 2, 'iterations': 455, 'distance': np.float64(0.9097966056639324), 'correlation': np.float64(0.40953562100175533), 'distance history': array([0.92187623, 0.92179421, 0.92171177, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37639177, 0.37672922, 0.37706751, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8603644708713456), 'distFC1': np.float64(0.9592287636279107)}
# sub 42 ; cond 1 : {'n_tau': 2, 'iterations': 681, 'distance': np.float64(0.9322401439311268), 'correlation': np.float64(0.3543205969752814), 'distance history': array([0.94993762, 0.94984938, 0.94975989, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30041403, 0.30090743, 0.30140554, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8966558249022478), 'distFC1': np.float64(0.9678245514555928)}
# sub 43 ; cond 0 : {'n_tau': 2, 'iterations': 411, 'distance': np.float64(0.9076297436564598), 'correlation': np.float64(0.4114052297670644), 'distance history': array([0.91617951, 0.91613545, 0.91609133, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38662318, 0.38674903, 0.38687501, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8666812048407243), 'distFC1': np.float64(0.9485785071443503)}
# sub 43 ; cond 1 : {'n_tau': 2, 'iterations': 170, 'distance': np.float64(0.9143561288785762), 'correlation': np.float64(0.37453360773060657), 'distance history': array([0.91984558, 0.91979277, 0.91973914, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36463587, 0.36493002, 0.36522535, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.852430427667059), 'distFC1': np.float64(0.9762829674824317)}
# sub 44 ; cond 0 : {'n_tau': 2, 'iterations': 758, 'distance': np.float64(0.8978163982662493), 'correlation': np.float64(0.4252909983787907), 'distance history': array([0.92327678, 0.92320239, 0.92312773, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36788341, 0.36808481, 0.36828674, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8628749553912785), 'distFC1': np.float64(0.9327579422921398)}
# sub 44 ; cond 1 : {'n_tau': 2, 'iterations': 282, 'distance': np.float64(0.9412252582766543), 'correlation': np.float64(0.32782544015005854), 'distance history': array([0.94405317, 0.9440299 , 0.94400653, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31929384, 0.31937017, 0.31944678, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9208284710022677), 'distFC1': np.float64(0.9616220677097325)}
# sub 45 ; cond 0 : {'n_tau': 2, 'iterations': 470, 'distance': np.float64(0.9255565341835688), 'correlation': np.float64(0.36939237476164544), 'distance history': array([0.93132534, 0.93129236, 0.93125937, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3523561 , 0.35245891, 0.35256172, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.893371505417547), 'distFC1': np.float64(0.9577415663382902)}
# sub 45 ; cond 1 : {'n_tau': 2, 'iterations': 479, 'distance': np.float64(0.9103580979326785), 'correlation': np.float64(0.4111434056180861), 'distance history': array([0.91994585, 0.9198505 , 0.91975468, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37743216, 0.37786959, 0.37830841, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8538191362335479), 'distFC1': np.float64(0.9668970749405383)}
# sub 46 ; cond 0 : {'n_tau': 2, 'iterations': 304, 'distance': np.float64(0.9245713922601986), 'correlation': np.float64(0.36987678868763635), 'distance history': array([0.92833045, 0.92830613, 0.92828173, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35671668, 0.35682611, 0.35693555, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8801947684280073), 'distFC1': np.float64(0.9689480441895512)}
# sub 46 ; cond 1 : {'n_tau': 2, 'iterations': 194, 'distance': np.float64(0.9415428848610409), 'correlation': np.float64(0.32165820869797696), 'distance history': array([0.94520069, 0.94516302, 0.94512524, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30901393, 0.30916105, 0.3093084 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9136110732307129), 'distFC1': np.float64(0.9694748072132622)}

# %% [markdown]
# ## logical OR, FC0p = 60, FC1p = 50

# %%
mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
n_cond=2

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

# model error #err_mod

err_mod_tmp = dict()
err_mod_tmp['sum EC'] = err_mod.flatten()
err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

err_mod_df = pd.DataFrame(err_mod_tmp)

plt.figure()
sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Sleep stage',fontsize=16)
plt.ylabel('Model error',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_fit_error.eps', format='eps')


# Pearson corr #fit_mod

fit_mod_tmp = dict()
fit_mod_tmp['sum EC'] = fit_mod.flatten()
fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

fit_mod_df = pd.DataFrame(fit_mod_tmp)

plt.figure()
sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Sleep stage',fontsize=16)
plt.ylabel('Model goodness of fit',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')


# Example EC

plt.figure(figsize=(5,4))
#plt.imshow(np.maximum(J_mod[18,1,:,:],0), cmap='Reds')
plt.imshow(J_mod[18,1,:,:], cmap='Reds')
plt.colorbar()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Target ROI index', fontsize=16)
plt.ylabel('Source ROI index', fontsize=16)
plt.tight_layout()
plt.savefig(res_dir+'example_EC.eps', format='eps')
# Out:
# /tmp/ipykernel_64911/2573013235.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_64911/2573013235.py:16: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_64911/2573013235.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_64911/2573013235.py:39: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
