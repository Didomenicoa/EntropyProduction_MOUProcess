# %% [markdown]
# ## Remember to use MOU conda environment

# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
 # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time (?)
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %% [markdown]
# # Model optimization

# %%
# data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N,dtype=bool)
regul_Sigma = 0.0
conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

min_val_EC = 0. # maximal value for EC
max_val_EC = 1. # maximal value for EC
min_val_Sigma = 0. # minimal value for Sigma

# arrays to store results
var_BOLD = np.zeros([n_sub,n_cond,N]) # empirical BOLD variance
J_mod = np.zeros([n_sub,n_cond,N,N]) # model Jacobian (EC)
Sigma_mod = np.zeros([n_sub,n_cond,N,N]) # model 
FC0_mod = np.zeros([n_sub,n_cond,N,N]) # model zero-lad FC
err_mod = np.zeros([n_sub,n_cond]) # model error
fit_mod = np.zeros([n_sub,n_cond]) # model goodness of fit (Pearson corr)

#0.008-0.09 Hz
#0.008 to 0.08 Hz

n_order = 3
TR = 2 # in seconds
Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01 / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')


# loop over subject and conditions
for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        # get time serie
        ts3=ts_all[0:68, :,i_sub,i_cond]
        filt_ts = spsg.filtfilt(b,a,ts3,axis=1)
        ts=stats.zscore(ts3, axis=1)       #mask_EC=mask_ECS
        
        # store empirical BOLD variance
        var_BOLD[i_sub,i_cond,:] = ts.var(axis=1)
            #mask_EC=mask_ECS
        FC0 = np.tensordot(ts[:,:-1], ts[:,:-1], axes=(1,1)) / 149
        FC0N=abs(FC0)/np.max(abs(FC0))
        
        lim_FC0= np.percentile(FC0N, 80)

        # anatomy-derived mask for existing connections for EC
        mask_EC1 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC1[FC0N>lim_FC0] = True
        for i in range(N):
            mask_EC1[i,i] = True # no self connection
            
        mask_EC = np.zeros([N,N],dtype=bool)
    
        #types of MASKS: 
        mask_EC=mask_EC1 
        
        # invert model
        mou_est = MOUv2()
        mou_est.fit(ts.T, mask_C=mask_EC, mask_Sigma=mask_Sigma, algo_version='true', min_iter=100, epsilon_C=0.005, epsilon_Sigma=0.005) #, verbose=True)

        # store results
        J_mod[i_sub,i_cond,:,:] = mou_est.J
        Sigma_mod[i_sub,i_cond,:,:] = mou_est.Sigma
        FC0_mod[i_sub,i_cond,:,:] = spl.solve_lyapunov(J_mod[i_sub,i_cond,:,:].T, -Sigma_mod[i_sub,i_cond,:,:])
        err_mod[i_sub,i_cond] = mou_est.d_fit['distance']
        fit_mod[i_sub,i_cond] = mou_est.d_fit['correlation']

        print('sub', i_sub, '; cond', i_cond, ':', mou_est.d_fit)

#%% save results
np.save(res_dir+'J_mod.npy',J_mod)
np.save(res_dir+'Sigma_mod.npy',Sigma_mod)
np.save(res_dir+'FC0_mod.npy',FC0_mod)

np.save(res_dir+'err_mod.npy',err_mod)
np.save(res_dir+'fit_mod.npy',fit_mod)

np.save(res_dir+'var_BOLD.npy',var_BOLD)
# Out:
# sub 0 ; cond 0 : {'n_tau': 2, 'iterations': 155, 'distance': np.float64(0.7997002955113592), 'correlation': np.float64(0.6276354356814476), 'distance history': array([0.91124857, 0.90991354, 0.90859553, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38559493, 0.38961945, 0.39358554, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7587334023686623), 'distFC1': np.float64(0.8407189204795565)}
# sub 0 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8529116131672516), 'correlation': np.float64(0.5692951150753528), 'distance history': array([0.91644941, 0.91338132, 0.91068658, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37261965, 0.39528616, 0.41552006, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9133075289003463), 'distFC1': np.float64(1.7431257440012424)}
# sub 1 ; cond 0 : {'n_tau': 2, 'iterations': 178, 'distance': np.float64(0.8350434770926394), 'correlation': np.float64(0.5808516802175827), 'distance history': array([0.92786437, 0.92689968, 0.92594443, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35744719, 0.36021454, 0.36295036, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8035893872104689), 'distFC1': np.float64(0.8665308801602333)}
# sub 1 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.7775504393540336), 'correlation': np.float64(0.5894243918825846), 'distance history': array([0.92529747, 0.92175367, 0.91874004, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33767279, 0.36361823, 0.38596137, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(51.82238271010081), 'distFC1': np.float64(2925.1596463435785)}
# sub 2 ; cond 0 : {'n_tau': 2, 'iterations': 121, 'distance': np.float64(0.8139626921955861), 'correlation': np.float64(0.6273223947838114), 'distance history': array([0.92278903, 0.92108613, 0.91942915, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36508626, 0.37276426, 0.38021378, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7567827350072935), 'distFC1': np.float64(0.8712345939308569)}
# sub 2 ; cond 1 : {'n_tau': 2, 'iterations': 118, 'distance': np.float64(0.8102683683802232), 'correlation': np.float64(0.6353105249398563), 'distance history': array([0.92576668, 0.92383043, 0.92195879, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36866451, 0.3781845 , 0.3873401 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7586035628743039), 'distFC1': np.float64(0.8619885038859304)}
# sub 3 ; cond 0 : {'n_tau': 2, 'iterations': 162, 'distance': np.float64(0.7992452653032975), 'correlation': np.float64(0.6025946609111292), 'distance history': array([0.91044425, 0.90932935, 0.90822587, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.
..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.40077105, 0.40499321, 0.40914747, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7445010769436826), 'distFC1': np.float64(0.8263810966261671)}
# sub 41 ; cond 1 : {'n_tau': 2, 'iterations': 188, 'distance': np.float64(0.8084787831266221), 'correlation': np.float64(0.6103023639822956), 'distance history': array([0.94891473, 0.94750741, 0.94612736, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30796808, 0.31328455, 0.31847698, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7975978165168893), 'distFC1': np.float64(0.8193975445638028)}
# sub 42 ; cond 0 : {'n_tau': 2, 'iterations': 152, 'distance': np.float64(0.779179169522113), 'correlation': np.float64(0.6831598685527691), 'distance history': array([0.92187623, 0.92016463, 0.91848401, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37639177, 0.38297399, 0.38939979, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7348121458140089), 'distFC1': np.float64(0.8235631897753313)}
# sub 42 ; cond 1 : {'n_tau': 2, 'iterations': 156, 'distance': np.float64(0.8424861095969258), 'correlation': np.float64(0.5989077717537874), 'distance history': array([0.94993762, 0.94852082, 0.94713966, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30041403, 0.30774843, 0.3148759 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8131817445817613), 'distFC1': np.float64(0.8718600956668485)}
# sub 43 ; cond 0 : {'n_tau': 2, 'iterations': 173, 'distance': np.float64(0.8017552322611394), 'correlation': np.float64(0.639814615748876), 'distance history': array([0.91617951, 0.91505012, 0.91393107, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38662318, 0.38974626, 0.39283374, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.766161894733617), 'distFC1': np.float64(0.8373842616977614)}
# sub 43 ; cond 1 : {'n_tau': 2, 'iterations': 123, 'distance': np.float64(0.814096237879365), 'correlation': np.float64(0.5997436630519287), 'distance history': array([0.91984558, 0.91813304, 0.91647471, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36463587, 0.37249694, 0.38008704, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7557259172657332), 'distFC1': np.float64(0.8725380107609569)}
# sub 44 ; cond 0 : {'n_tau': 2, 'iterations': 186, 'distance': np.float64(0.7996543793368365), 'correlation': np.float64(0.6371581335524588), 'distance history': array([0.92327678, 0.92217236, 0.92107797, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36788341, 0.37082478, 0.37373373, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7694632138756756), 'distFC1': np.float64(0.82986883173155)}
# sub 44 ; cond 1 : {'n_tau': 2, 'iterations': 170, 'distance': np.float64(0.8500812647882157), 'correlation': np.float64(0.5649257160971641), 'distance history': array([0.94405317, 0.9429946 , 0.94194776, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31929384, 0.3226808 , 0.3260245 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.840803855220666), 'distFC1': np.float64(0.8593864013427316)}
# sub 45 ; cond 0 : {'n_tau': 2, 'iterations': 151, 'distance': np.float64(0.8303913253483415), 'correlation': np.float64(0.5998243833677773), 'distance history': array([0.93132534, 0.93012384, 0.92893488, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3523561 , 0.35606902, 0.35973349, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8057559089488016), 'distFC1': np.float64(0.8550395600004354)}
# sub 45 ; cond 1 : {'n_tau': 2, 'iterations': 136, 'distance': np.float64(0.8045112617417873), 'correlation': np.float64(0.653848553659182), 'distance history': array([0.91994585, 0.91818127, 0.9164593 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37743216, 0.38489684, 0.39215279, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7496415332312509), 'distFC1': np.float64(0.8594365632293569)}
# sub 46 ; cond 0 : {'n_tau': 2, 'iterations': 135, 'distance': np.float64(0.8400737665016527), 'correlation': np.float64(0.582870487226588), 'distance history': array([0.92833045, 0.92707289, 0.9258346 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35671668, 0.36148706, 0.36616712, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.796330084981413), 'distFC1': np.float64(0.8838218442818097)}
# sub 46 ; cond 1 : {'n_tau': 2, 'iterations': 120, 'distance': np.float64(0.8977528704459736), 'correlation': np.float64(0.4510764400652242), 'distance history': array([0.94520069, 0.94444583, 0.94370173, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30901393, 0.31175389, 0.3144507 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8757241502272243), 'distFC1': np.float64(0.9198072175954366)}

# %%
plt.imshow(mask_EC1)

# %% [markdown]
# ## Check goodness of fit :

# %%
mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
n_cond=2

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

# model error #err_mod

err_mod_tmp = dict()
err_mod_tmp['sum EC'] = err_mod.flatten()
err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

err_mod_df = pd.DataFrame(err_mod_tmp)

plt.figure()
sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model error',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_fit_error.eps', format='eps')


# Pearson corr #fit_mod

fit_mod_tmp = dict()
fit_mod_tmp['sum EC'] = fit_mod.flatten()
fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

fit_mod_df = pd.DataFrame(fit_mod_tmp)

plt.figure()
sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model goodness of fit',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')


# Example EC

plt.figure(figsize=(5,4))
#plt.imshow(np.maximum(J_mod[18,1,:,:],0), cmap='Reds')
plt.imshow(J_mod[18,1,:,:], cmap='Reds')
plt.colorbar()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Target ROI index', fontsize=16)
plt.ylabel('Source ROI index', fontsize=16)
plt.tight_layout()
plt.savefig(res_dir+'example_EC.eps', format='eps')
# Out:
# /tmp/ipykernel_5995/4027539692.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5995/4027539692.py:16: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5995/4027539692.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5995/4027539692.py:39: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)

# %% [markdown]
# ## ENTROPY CALCULATION

# %%
# transpose to Saclay's framework
EPR = np.zeros([n_sub,n_cond])
Q_indiv = np.zeros([n_sub,n_cond,N,N])

for i_sub in range(n_sub):
    for i_cond in range(n_cond):

        try:
            B = np.copy(-J_mod[i_sub,i_cond,:,:].T)
            D = np.copy(0.5 * Sigma_mod[i_sub,i_cond,:,:])
            S = np.copy(FC0_mod[i_sub,i_cond,:,:])
            
            Q = np.dot(B, S) - D
            Q_indiv[i_sub,i_cond,:,:] = Q
            
            # sanity check
            if True:
                print('should be close to zero:', np.abs(np.dot(B,S) + np.dot(S,B.T) -2*D).max())
            
            # formula from Godreche Luck
            Dinv = np.linalg.pinv(D)
            Sinv = np.linalg.pinv(S)
            
            entropy_prod_rate = -np.trace(np.dot(np.dot(np.dot(Sinv, Q), Dinv), Q))
            EPR[i_sub,i_cond] = entropy_prod_rate

        except:
            print('problem with subject/cond:', i_sub, i_cond)
# Out:
# should be close to zero: 7.105427357601002e-15
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 9.547918011776346e-15
# should be close to zero: 3.9968028886505635e-14
# should be close to zero: 2.5757174171303632e-14
# should be close to zero: 2.4424906541753444e-14
# should be close to zero: 1.0436096431476471e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 2.2648549702353193e-14
# should be close to zero: 1.0880185641326534e-14
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 7.993605777301127e-15
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 1.1025902413308586e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.3766765505351941e-14
# should be close to zero: 5.329070518200751e-15
# should be close to zero: 3.019806626980426e-14
# should be close to zero: 2.3092638912203256e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 0.0
# should be close to zero: 8.215650382226158e-15
# should be close to zero: 4.618527782440651e-14
# should be close to zero: 9.103828801926284e-15
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 3.4638958368304884e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 3.2862601528904634e-14
# should be close to zero: 5.329070518200751e-15
# should be close to zero: 2.842170943040401e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 1.6431300764452317e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 1.0436096431476471e-14
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 3.730349362740526e-14
# should be close to zero: 8.659739592076221e-15
# should be close to zero: 3.019806626980426e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 5.861977570020827e-14
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 1.6431300764452317e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 3.4416913763379853e-15
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 1.7319479184152442e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 6.8833827526759706e-15
# should be close to zero: 2.930988785010413e-14
# should be close to zero: 1.9095836023552692e-14
# should be close to zero: 3.108624468950438e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 1.3766765505351941e-14
# should be close to zero: 8.958112029944232e-15
# should be close to zero: 3.375077994860476e-14
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 2.930988785010413e-14
# should be close to zero: 1.2948409705559882e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 2.4868995751603507e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 1.7985612998927536e-14
# should be close to zero: 8.659739592076221e-15
# should be close to zero: 1.509903313490213e-14
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 3.6415315207705135e-14
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 1.1324274851176597e-14
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 1.7763568394002505e-14

# %%
#%% plots

matplotlib.rc('font', size=12) 
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]]
cols2 = [[0.7,0.7,1],[0.6,0.6,1],[0.5,0.5,1],[0.4,0.4,1]]

EPR_tmp = dict()
EPR_tmp['sleep stage'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()
EPR_tmp['EPR'] = EPR.flatten()

EPR_df = pd.DataFrame(EPR_tmp)


# real data

plt.figure()
ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
sb.swarmplot(data=EPR_df, x='sleep stage', y='EPR', color=[0.7,0.7,0.7])
plt.axis(ymin=0, ymax=5)

plt.xlabel('Condition', fontsize=12)
plt.ylabel('Entropy production rate', fontsize=12)

plt.savefig(res_dir+'entropy_prod_rate.eps', format='eps')
# Out:
# /tmp/ipykernel_5995/2923277758.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
# /tmp/ipykernel_5995/2923277758.py:20: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)

# %%
EPR_df
# Out:
#    sleep stage       EPR
# 0          CTR  1.336240
# 1          SCZ  1.886413
# 2          CTR  1.044613
# 3          SCZ  4.073236
# 4          CTR  1.871051
# ..         ...       ...
# 89         SCZ  0.703001
# 90         CTR  0.617269
# 91         SCZ  1.241530
# 92         CTR  1.202480
# 93         SCZ  1.139202
#
# [94 rows x 2 columns]

# %% [markdown]
# Verify that the two groups are
# ## Statistically Different

# %% [markdown]
# 3. Check if the two groups are statistically different: WELCH TEST

# %%
CTR = EPR[:,0]
SCZ = EPR[:,1]
stat_t, p_t = stats.ttest_ind(CTR, SCZ, equal_var=False)

print(f"Welch's t-test statistic: {stat_t:.3f}, p-value: {p_t:.3f}")

if p_t < 0.05:
    print("The difference between groups is statistically significant.")
else:
    print("No significant difference between groups.")
# Out:
# Welch's t-test statistic: -3.617, p-value: 0.001
# The difference between groups is statistically significant.
