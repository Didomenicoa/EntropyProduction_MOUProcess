# %% [markdown]
# ## Remember to use MOU conda environment

# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
 # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time (?)
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %% [markdown]
# # Model optimization

# %%
# data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N,dtype=bool)
regul_Sigma = 0.0
conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

min_val_EC = 0. # maximal value for EC
max_val_EC = 1. # maximal value for EC
min_val_Sigma = 0. # minimal value for Sigma

# arrays to store results
var_BOLD = np.zeros([n_sub,n_cond,N]) # empirical BOLD variance
J_mod = np.zeros([n_sub,n_cond,N,N]) # model Jacobian (EC)
Sigma_mod = np.zeros([n_sub,n_cond,N,N]) # model 
FC0_mod = np.zeros([n_sub,n_cond,N,N]) # model zero-lad FC
err_mod = np.zeros([n_sub,n_cond]) # model error
fit_mod = np.zeros([n_sub,n_cond]) # model goodness of fit (Pearson corr)

#0.008-0.09 Hz
#0.008 to 0.08 Hz

n_order = 3
TR = 2 # in seconds
Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01 / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')


# loop over subject and conditions
for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        # get time serie
        ts3=ts_all[0:68, :,i_sub,i_cond]
        filt_ts = spsg.filtfilt(b,a,ts3,axis=1)
        ts=stats.zscore(ts3, axis=1)       #mask_EC=mask_ECS
        
        # store empirical BOLD variance
        var_BOLD[i_sub,i_cond,:] = ts.var(axis=1)
            #mask_EC=mask_ECS
        FC0 = np.tensordot(ts[:,:-1], ts[:,:-1], axes=(1,1)) / 149
        FC1 = np.tensordot(ts[:,:-1], ts[:,1:], axes=(1,1)) / 149
        FC0N=abs(FC0)/np.max(abs(FC0))
        FC1N=abs(FC1)/np.max(abs(FC1))
        
        lim_FC0= np.percentile(FC0N, 20)
        lim_FC1= np.percentile(FC1N, 10)

        # anatomy-derived mask for existing connections for EC
        mask_EC1 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC1[FC0N>lim_FC0] = True
        for i in range(N):
            mask_EC1[i,i] = True # no self connection
            
        
        mask_EC2 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC2[abs(FC1N)>lim_FC1] = True
        for i in range(N):
            mask_EC2[i,i] = False # no self connection
            
        mask_EC = np.zeros([N,N],dtype=bool)
    
        #types of MASKS: 
        mask_EC=mask_EC1 
        
        # invert model
        mou_est = MOUv2()
        mou_est.fit(ts.T, mask_C=mask_EC, mask_Sigma=mask_Sigma, algo_version='true', min_iter=100, epsilon_C=0.005, epsilon_Sigma=0.005) #, verbose=True)

        # store results
        J_mod[i_sub,i_cond,:,:] = mou_est.J
        Sigma_mod[i_sub,i_cond,:,:] = mou_est.Sigma
        FC0_mod[i_sub,i_cond,:,:] = spl.solve_lyapunov(J_mod[i_sub,i_cond,:,:].T, -Sigma_mod[i_sub,i_cond,:,:])
        err_mod[i_sub,i_cond] = mou_est.d_fit['distance']
        fit_mod[i_sub,i_cond] = mou_est.d_fit['correlation']

        print('sub', i_sub, '; cond', i_cond, ':', mou_est.d_fit)

#%% save results
np.save(res_dir+'J_mod.npy',J_mod)
np.save(res_dir+'Sigma_mod.npy',Sigma_mod)
np.save(res_dir+'FC0_mod.npy',FC0_mod)

np.save(res_dir+'err_mod.npy',err_mod)
np.save(res_dir+'fit_mod.npy',fit_mod)

np.save(res_dir+'var_BOLD.npy',var_BOLD)
# Out:
# sub 0 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8536701078121244), 'correlation': np.float64(0.576152738483642), 'distance history': array([0.91124857, 0.90937863, 0.90753094, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38559493, 0.39138742, 0.39710599, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8079359492839344), 'distFC1': np.float64(0.9905861435064142)}
# sub 0 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8804913159613559), 'correlation': np.float64(0.6229551676467696), 'distance history': array([0.91644941, 0.91221256, 0.90855817, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37261965, 0.40703082, 0.43764933, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(17.84597314613625), 'distFC1': np.float64(604958490.3543404)}
# sub 1 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8734800132040075), 'correlation': np.float64(0.5342620028515843), 'distance history': array([0.92786437, 0.92625073, 0.92465227, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35744719, 0.36217945, 0.3668643 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8577043002957451), 'distFC1': np.float64(0.9413449058428454)}
# sub 1 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.845021145199484), 'correlation': np.float64(0.5719110131026046), 'distance history': array([0.92529747, 0.91940915, 0.91464043, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33767279, 0.38916759, 0.43097818, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(19.474775263142856), 'distFC1': np.float64(198294793.77188957)}
# sub 2 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8694956395627788), 'correlation': np.float64(0.6079535567602272), 'distance history': array([0.92278903, 0.92036491, 0.91800596, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36508626, 0.37672223, 0.38804304, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.4306086014034096), 'distFC1': np.float64(11.82518895689062)}
# sub 2 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8658545798054165), 'correlation': np.float64(0.6257768419729821), 'distance history': array([0.92576668, 0.92302384, 0.92038061, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36866451, 0.38263461, 0.39607537, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8579015992159991), 'distFC1': np.float64(1.749595058085907)}
# sub 3 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8414784662046337), 'correlation': np.float64(0.5595303651353802), 'distance history': array([0.91044425, 0.90860866, 0.90678905, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38546301, 0.39012482, 0.39472912, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8485108611921662), 'distFC1': np.float64(0.9812311717585223)}
# sub 3 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8649723282093728), 'correlation': np.float64(0.5620571180479889), 'distance history': array([0.92163889, 0.91976015, 0.91790581, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37318216, 0.3794453 , 0.38560389, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.2652145961237657), 'distFC1': np.float64(2.164015066524281)}
# sub 4 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9037099303252707), 'correlation': np.float64(0.5787854097402186), 'distance history': array([0.97302606, 0.97046688, 0.96806539, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.22235662, 0.24103611, 0.25872967, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9089514139083211), 'distFC1': np.float64(1.2767694584185703)}
# sub 4 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8610554538442732), 'correlation': np.float64(0.5453867054256649), 'distance history': array([0.91466401, 0.91302274, 0.91139594, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38455424, 0.38905932, 0.39351926, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8376127955930245), 'distFC1': np.float64(0.9534619594547687)}
# sub 5 ; cond 0 : {'n_tau': 2, 'iterations': 120, 'distance': np.float64(0.8254983970773879), 'correlation': np.float64(0.654710695396987), 'distance history': array([0.93913396, 0.93750331, 0.93588868, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33369178, 0.33887527, 0.34400166, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8082697787959627), 'distFC1': np.float64(0.8597987242858547)}
# sub 5 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8534160206594876), 'correlation': np.float64(0.555191906145438), 'distance history': array([0.9072987 , 0.90563589, 0.90398682, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39855279, 0.40305402, 0.40750923, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8253602357238505), 'distFC1': np.float64(0.9515772193673098)}
# sub 6 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.891751240983545), 'correlation': np.float64(0.5211739065522212), 'distance history': array([0.93712397, 0.93542114, 0.93374025, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34052594, 0.34696798, 0.35331447, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8388777691533291), 'distFC1': np.float64(1.0123986645392338)}
# sub 6 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8629119316639028), 'correlation': np.float64(0.5863545501607216), 'distance history': array([0.92774293, 0.92572465, 0.92373559, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36274452, 0.36987535, 0.37687814, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8417856702904953), 'distFC1': np.float64(0.9800433246406146)}
# sub 7 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.862357355166107), 'correlation': np.float64(0.562728605376485), 'distance history': array([0.92218653, 0.92033785, 0.91851135, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36061937, 0.36639931, 0.37210945, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8200226437027698), 'distFC1': np.float64(0.9821005732807223)}
# sub 7 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8740883136971127), 'correlation': np.float64(0.5627677657107139), 'distance history': array([0.94240077, 0.94054628, 0.93871772, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31683674, 0.32349828, 0.3300605 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8760257109459749), 'distFC1': np.float64(0.9622736734911591)}
# sub 8 ; cond 0 : {'n_tau': 2, 'iterations': 110, 'distance': np.float64(0.8487877962086683), 'correlation': np.float64(0.6214163965668966), 'distance history': array([0.92098727, 0.91945387, 0.91793156, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3757234 , 0.37972236, 0.38368486, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8185448050773503), 'distFC1': np.float64(0.8797197477052814)}
# sub 8 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8715891287879265), 'correlation': np.float64(0.6229639526925141), 'distance history': array([0.89655441, 0.89099819, 0.88670796, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38556293, 0.44362417, 0.49075845, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(2.0951916587023884), 'distFC1': np.float64(356659497.6647414)}
# sub 9 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8639943800402592), 'correlation': np.float64(0.595571741650404), 'distance history': array([0.91563486, 0.91347793, 0.91135736, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36812487, 0.37776126, 0.38723462, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.0973961865406787), 'distFC1': np.float64(4.225481918459498)}
# sub 9 ; cond 1 : {'n_tau': 2, 'iterations': 103, 'distance': np.float64(0.8739032101279949), 'correlation': np.float64(0.5926806711345843), 'distance history': array([0.95682231, 0.95489953, 0.95300869, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.27578926, 0.28342715, 0.29093471, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8524251283997603), 'distFC1': np.float64(0.9148261109773015)}
# sub 10 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8606564466576863), 'correlation': np.float64(0.5640155244450213), 'distance history': array([0.91639589, 0.91460493, 0.9128344 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38033351, 0.38576681, 0.39113271, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8182176073125643), 'distFC1': np.float64(0.9489222686922403)}
# sub 10 ; cond 1 : {'n_tau': 2, 'iterations': 103, 'distance': np.float64(0.8560965503094056), 'correlation': np.float64(0.6876601774663631), 'distance history': array([0.93087847, 0.92870744, 0.92659121, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34406863, 0.35319868, 0.36211967, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7911300423647858), 'distFC1': np.float64(0.9337140503584307)}
# sub 11 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8690472237826344), 'correlation': np.float64(0.58653216177716), 'distance history': array([0.92954097, 0.92759672, 0.92568503, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35720482, 0.36438816, 0.37144468, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8305491593696781), 'distFC1': np.float64(0.9597495597755528)}
# sub 11 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9705225901319199), 'correlation': np.float64(0.21387551148949524), 'distance history': array([ 0.97052259,  4.99059728, 27.89466034, ...,  0.        ,
#         0.        ,  0.        ]), 'correlation history': array([ 0.21387551, -0.08799477,  0.13390207, ...,  0.        ,
#         0.        ,  0.        ]), 'distFC0': np.float64(0.9525686009637061), 'distFC1': np.float64(151988759.26165926)}
# sub 12 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8711348828938519), 'correlation': np.float64(0.5386365427400072), 'distance history': array([0.92510562, 0.92340124, 0.92171229, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35931972, 0.36459071, 0.36980622, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.825413198253957), 'distFC1': np.float64(0.9322994147746323)}
# sub 12 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8788464563754188), 'correlation': np.float64(0.6207459759378464), 'distance history': array([0.91273064, 0.90886547, 0.90540828, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37150045, 0.40341702, 0.4325868 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(30.96477058300353), 'distFC1': np.float64(621373119.7537166)}
# sub 13 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8711850295045582), 'correlation': np.float64(0.507572419223214), 'distance history': array([0.95016628, 0.94823598, 0.94633052, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.2902577 , 0.29615454, 0.30194702, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8997723204932685), 'distFC1': np.float64(0.9732269468319108)}
# sub 13 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.840050557428472), 'correlation': np.float64(0.5927862653446978), 'distance history': array([0.90963037, 0.90756365, 0.90552345, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37807936, 0.38439121, 0.39061276, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8143359454099416), 'distFC1': np.float64(1.0054316202139617)}
# sub 14 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8706317466990601), 'correlation': np.float64(0.6507471147292265), 'distance history': array([0.91330509, 0.90709796, 0.902232  , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38138719, 0.43617075, 0.48021065, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(73.562643675334), 'distFC1': np.float64(6955293.062404328)}
# sub 14 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8595323342963497), 'correlation': np.float64(0.6217749631147298), 'distance history': array([0.92431845, 0.9217455 , 0.91926172, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35287104, 0.36521385, 0.37716855, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.1238266594744413), 'distFC1': np.float64(3.690345787683536)}
# sub 15 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8832545938699075), 'correlation': np.float64(0.6047019752851851), 'distance history': array([0.94521891, 0.94297349, 0.94078972, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.32099858, 0.33200407, 0.34271099, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8257683662784443), 'distFC1': np.float64(0.9575710139457165)}
# sub 15 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8940349884037646), 'correlation': np.float64(0.5970766240262495), 'distance history': array([0.92235288, 0.91787272, 0.91414731, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35310631, 0.39743234, 0.43560658, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(6.208899915040267), 'distFC1': np.float64(489531911.9681407)}
# sub 16 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8612731946462928), 'correlation': np.float64(0.5428849829874276), 'distance history': array([0.91443823, 0.9128637 , 0.91129973, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39080206, 0.39482797, 0.39882119, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8439542468041503), 'distFC1': np.float64(0.931907601607292)}
# sub 16 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.
..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8094315115771934), 'distFC1': np.float64(1.036606279253596)}
# sub 30 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8556288635216185), 'correlation': np.float64(0.5641728292097905), 'distance history': array([0.91969911, 0.9179008 , 0.91611905, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37426086, 0.37927868, 0.38424048, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8701782701132224), 'distFC1': np.float64(1.012702193581169)}
# sub 31 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8803603184610087), 'correlation': np.float64(0.6183755819962048), 'distance history': array([0.92497947, 0.9218185 , 0.91887545, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36010787, 0.38118453, 0.40103413, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(97.5107520264965), 'distFC1': np.float64(108656262.50033371)}
# sub 31 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8702239291361864), 'correlation': np.float64(0.5852588483328804), 'distance history': array([0.9242142 , 0.9222187 , 0.92026045, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36066666, 0.36884849, 0.37688064, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(77.08630058092803), 'distFC1': np.float64(196.73901664506)}
# sub 32 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8679832677027088), 'correlation': np.float64(0.6215623351975741), 'distance history': array([0.91260008, 0.90948274, 0.90655894, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38179158, 0.40104423, 0.41924276, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(184.97364686600838), 'distFC1': np.float64(94229037.63893117)}
# sub 32 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.878550070773787), 'correlation': np.float64(0.6348386017459975), 'distance history': array([0.92587331, 0.92249058, 0.91937723, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35930154, 0.38185321, 0.40291161, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(49.7037544460596), 'distFC1': np.float64(148231271.9353363)}
# sub 33 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8515656921975903), 'correlation': np.float64(0.5868218267077681), 'distance history': array([0.91073468, 0.90883778, 0.90696093, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.39529543, 0.4013791 , 0.40737247, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8023502033720236), 'distFC1': np.float64(0.9457215352148363)}
# sub 33 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9083469777874693), 'correlation': np.float64(0.47506937808347044), 'distance history': array([0.94680318, 0.94463378, 0.94252562, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.29975659, 0.31513885, 0.32985511, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(133.88604103795797), 'distFC1': np.float64(921805617.0223397)}
# sub 34 ; cond 0 : {'n_tau': 2, 'iterations': 104, 'distance': np.float64(0.8632743454517189), 'correlation': np.float64(0.6140624603944966), 'distance history': array([0.92570226, 0.92349124, 0.92133391, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35640215, 0.36579928, 0.37498899, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.7755247915403577), 'distFC1': np.float64(0.9514029695254915)}
# sub 34 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8896026636335639), 'correlation': np.float64(0.5268218877797478), 'distance history': array([0.9290633 , 0.92726057, 0.92548619, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35224599, 0.35993914, 0.36750081, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(58.407935205393855), 'distFC1': np.float64(174347259.71896726)}
# sub 35 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8716582798950745), 'correlation': np.float64(0.5399298358789737), 'distance history': array([0.93591906, 0.93424709, 0.93259034, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3366862 , 0.34164465, 0.34654927, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8841285106447981), 'distFC1': np.float64(0.969766054145589)}
# sub 35 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8922132823429966), 'correlation': np.float64(0.5940747887377813), 'distance history': array([0.92085509, 0.91666306, 0.91310643, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36417117, 0.40710101, 0.44408057, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(11.645571617405107), 'distFC1': np.float64(45114656.953636885)}
# sub 36 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.864251979118891), 'correlation': np.float64(0.5586203702184661), 'distance history': array([0.91480047, 0.91313503, 0.91148564, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38734071, 0.39231292, 0.397236  , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.829498782601674), 'distFC1': np.float64(1.0154304371596699)}
# sub 36 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8677521272053963), 'correlation': np.float64(0.5812813096168075), 'distance history': array([0.9292016 , 0.92693361, 0.92471688, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.34451046, 0.35383366, 0.3629397 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.094209715180685), 'distFC1': np.float64(9.702536499269506)}
# sub 37 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.
; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.860835771229508), 'correlation': np.float64(0.5469280361712718), 'distance history': array([0.92327678, 0.92158484, 0.91990638, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36788341, 0.37240317, 0.37687779, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8825421104723642), 'distFC1': np.float64(0.9730288500841966)}
# sub 44 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8858046777958899), 'correlation': np.float64(0.5222361672191396), 'distance history': array([0.94405317, 0.94238682, 0.94073887, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31929384, 0.32468274, 0.33000772, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8841990556043231), 'distFC1': np.float64(0.9591525125717776)}
# sub 45 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8667970211456999), 'correlation': np.float64(0.568320582266471), 'distance history': array([0.93132534, 0.92956634, 0.927826  , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3523561 , 0.35787787, 0.3633329 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8786983776131562), 'distFC1': np.float64(0.9979471850902354)}
# sub 45 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.862258362374931), 'correlation': np.float64(0.6240049728465381), 'distance history': array([0.91994585, 0.91755301, 0.91522179, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37743216, 0.38799284, 0.39827396, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8413702172713219), 'distFC1': np.float64(1.3933484359773491)}
# sub 46 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8796459217009839), 'correlation': np.float64(0.5631817375605139), 'distance history': array([0.92833045, 0.92645122, 0.92460011, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35671668, 0.36436036, 0.37187961, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(3.2402225802047373), 'distFC1': np.float64(8.859783922580217)}
# sub 46 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.9014379982420448), 'correlation': np.float64(0.4901634404089276), 'distance history': array([0.94520069, 0.94356765, 0.94195607, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30901393, 0.31528435, 0.32146995, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8828922412672109), 'distFC1': np.float64(1.1629348530964863)}

# %%
plt.imshow(mask_EC1)

# %% [markdown]
# ## Check goodness of fit :

# %%
mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
n_cond=2

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

# model error #err_mod

err_mod_tmp = dict()
err_mod_tmp['sum EC'] = err_mod.flatten()
err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

err_mod_df = pd.DataFrame(err_mod_tmp)

plt.figure()
sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model error',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_fit_error.eps', format='eps')


# Pearson corr #fit_mod

fit_mod_tmp = dict()
fit_mod_tmp['sum EC'] = fit_mod.flatten()
fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

fit_mod_df = pd.DataFrame(fit_mod_tmp)

plt.figure()
sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model goodness of fit',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')


# Example EC

plt.figure(figsize=(5,4))
#plt.imshow(np.maximum(J_mod[18,1,:,:],0), cmap='Reds')
plt.imshow(J_mod[18,1,:,:], cmap='Reds')
plt.colorbar()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Target ROI index', fontsize=16)
plt.ylabel('Source ROI index', fontsize=16)
plt.tight_layout()
plt.savefig(res_dir+'example_EC.eps', format='eps')
# Out:
# /tmp/ipykernel_74534/4027539692.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_74534/4027539692.py:16: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_74534/4027539692.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_74534/4027539692.py:39: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)

# %% [markdown]
# ## ENTROPY CALCULATION

# %%
# transpose to Saclay's framework
EPR = np.zeros([n_sub,n_cond])
Q_indiv = np.zeros([n_sub,n_cond,N,N])

for i_sub in range(n_sub):
    for i_cond in range(n_cond):

        try:
            B = np.copy(-J_mod[i_sub,i_cond,:,:].T)
            D = np.copy(0.5 * Sigma_mod[i_sub,i_cond,:,:])
            S = np.copy(FC0_mod[i_sub,i_cond,:,:])
            
            Q = np.dot(B, S) - D
            Q_indiv[i_sub,i_cond,:,:] = Q
            
            # sanity check
            if True:
                print('should be close to zero:', np.abs(np.dot(B,S) + np.dot(S,B.T) -2*D).max())
            
            # formula from Godreche Luck
            Dinv = np.linalg.pinv(D)
            Sinv = np.linalg.pinv(S)
            
            entropy_prod_rate = -np.trace(np.dot(np.dot(np.dot(Sinv, Q), Dinv), Q))
            EPR[i_sub,i_cond] = entropy_prod_rate

        except:
            print('problem with subject/cond:', i_sub, i_cond)
# Out:
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 2.842170943040401e-14
# should be close to zero: 4.884981308350689e-15
# should be close to zero: 2.3092638912203256e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 1.7763568394002505e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 4.4027281820291364e-15
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 5.10702591327572e-15
# should be close to zero: 2.842170943040401e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 1.509903313490213e-14
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 0.0
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 7.771561172376096e-15
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 3.108624468950438e-14
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 2.398081733190338e-14
# should be close to zero: 5.773159728050814e-15
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 6.217248937900877e-15
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 6.217248937900877e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 1.509903313490213e-14
# should be close to zero: 7.771561172376096e-15
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 3.552713678800501e-14
# should be close to zero: 1.0436096431476471e-14
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 3.730349362740526e-14
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 5.10702591327572e-15
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 5.329070518200751e-15
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 5.773159728050814e-15
# should be close to zero: 2.842170943040401e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 1.865174681370263e-14
# should be close to zero: 3.019806626980426e-14
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 7.993605777301127e-15
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 6.439293542825908e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 5.551115123125783e-15
# should be close to zero: 6.217248937900877e-15
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 1.865174681370263e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 1.1546319456101628e-14

# %%
#%% plots

matplotlib.rc('font', size=12) 
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]]
cols2 = [[0.7,0.7,1],[0.6,0.6,1],[0.5,0.5,1],[0.4,0.4,1]]

EPR_tmp = dict()
EPR_tmp['sleep stage'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()
EPR_tmp['EPR'] = EPR.flatten()

EPR_df = pd.DataFrame(EPR_tmp)


# real data

plt.figure()
ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
sb.swarmplot(data=EPR_df, x='sleep stage', y='EPR', color=[0.7,0.7,0.7])
plt.axis(ymin=0, ymax=5)

plt.xlabel('Condition', fontsize=12)
plt.ylabel('Entropy production rate', fontsize=12)

plt.savefig(res_dir+'entropy_prod_rate.eps', format='eps')
# Out:
# /tmp/ipykernel_74534/2923277758.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
# /tmp/ipykernel_74534/2923277758.py:20: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)

# %%
EPR_df
# Out:
#    sleep stage       EPR
# 0          CTR  0.512423
# 1          SCZ  1.056541
# 2          CTR  0.389805
# 3          SCZ  1.854968
# 4          CTR  0.780562
# ..         ...       ...
# 89         SCZ  0.361834
# 90         CTR  0.421673
# 91         SCZ  0.508373
# 92         CTR  0.616807
# 93         SCZ  0.649429
#
# [94 rows x 2 columns]

# %% [markdown]
# Verify that the two groups are
# ## Statistically Different

# %% [markdown]
# 3. Check if the two groups are statistically different: WELCH TEST

# %%
CTR = EPR[:,0]
SCZ = EPR[:,1]
stat_t, p_t = stats.ttest_ind(CTR, SCZ, equal_var=False)

print(f"Welch's t-test statistic: {stat_t:.3f}, p-value: {p_t:.3f}")

if p_t < 0.05:
    print("The difference between groups is statistically significant.")
else:
    print("No significant difference between groups.")
# Out:
# Welch's t-test statistic: -1.410, p-value: 0.162
# No significant difference between groups.
