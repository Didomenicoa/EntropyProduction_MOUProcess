# %% [markdown]
# ## Remember to use MOU conda environment

# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
 # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time (?)
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %% [markdown]
# # Model optimization

# %%
# data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N,dtype=bool)
regul_Sigma = 0.0
conds = ['CTR', 'SCZ']
n_cond = len(conds) # number of conditions

min_val_EC = 0. # maximal value for EC
max_val_EC = 1. # maximal value for EC
min_val_Sigma = 0. # minimal value for Sigma

# arrays to store results
var_BOLD = np.zeros([n_sub,n_cond,N]) # empirical BOLD variance
J_mod = np.zeros([n_sub,n_cond,N,N]) # model Jacobian (EC)
Sigma_mod = np.zeros([n_sub,n_cond,N,N]) # model 
FC0_mod = np.zeros([n_sub,n_cond,N,N]) # model zero-lad FC
err_mod = np.zeros([n_sub,n_cond]) # model error
fit_mod = np.zeros([n_sub,n_cond]) # model goodness of fit (Pearson corr)

#0.008-0.09 Hz
#0.008 to 0.08 Hz

n_order = 3
TR = 2 # in seconds
Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01 / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')


# loop over subject and conditions
for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        # get time serie
        ts3=ts_all[0:68, :,i_sub,i_cond]
        filt_ts = spsg.filtfilt(b,a,ts3,axis=1)
        ts=stats.zscore(ts3, axis=1)       #mask_EC=mask_ECS
        
        # store empirical BOLD variance
        var_BOLD[i_sub,i_cond,:] = ts.var(axis=1)
            #mask_EC=mask_ECS
        FC0 = np.tensordot(ts[:,:-1], ts[:,:-1], axes=(1,1)) / 149
        FC0N=abs(FC0)/np.max(abs(FC0))
        
        lim_FC0= np.percentile(FC0N, 40)

        # anatomy-derived mask for existing connections for EC
        mask_EC1 = np.zeros([N,N],dtype=bool) # EC weights to tune
        mask_EC1[FC0N>lim_FC0] = True
        for i in range(N):
            mask_EC1[i,i] = True # no self connection
            
        mask_EC = np.zeros([N,N],dtype=bool)
    
        #types of MASKS: 
        mask_EC=mask_EC1 
        
        # invert model
        mou_est = MOUv2()
        mou_est.fit(ts.T, mask_C=mask_EC, mask_Sigma=mask_Sigma, algo_version='true', min_iter=100, epsilon_C=0.005, epsilon_Sigma=0.005) #, verbose=True)

        # store results
        J_mod[i_sub,i_cond,:,:] = mou_est.J
        Sigma_mod[i_sub,i_cond,:,:] = mou_est.Sigma
        FC0_mod[i_sub,i_cond,:,:] = spl.solve_lyapunov(J_mod[i_sub,i_cond,:,:].T, -Sigma_mod[i_sub,i_cond,:,:])
        err_mod[i_sub,i_cond] = mou_est.d_fit['distance']
        fit_mod[i_sub,i_cond] = mou_est.d_fit['correlation']

        print('sub', i_sub, '; cond', i_cond, ':', mou_est.d_fit)

#%% save results
np.save(res_dir+'J_mod.npy',J_mod)
np.save(res_dir+'Sigma_mod.npy',Sigma_mod)
np.save(res_dir+'FC0_mod.npy',FC0_mod)

np.save(res_dir+'err_mod.npy',err_mod)
np.save(res_dir+'fit_mod.npy',fit_mod)

np.save(res_dir+'var_BOLD.npy',var_BOLD)
# Out:
# sub 0 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8415923254814526), 'correlation': np.float64(0.5984355291380022), 'distance history': array([0.91124857, 0.9094731 , 0.90771933, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38559493, 0.39102887, 0.39638997, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.8514497247585406), 'distFC1': np.float64(2.9602861357095476)}
# sub 0 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8731557480784267), 'correlation': np.float64(0.6146590174857597), 'distance history': array([0.91644941, 0.91235647, 0.90881605, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37261965, 0.40474132, 0.43331373, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(34.59748829289543), 'distFC1': np.float64(184180.35276478497)}
# sub 1 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8616031673301281), 'correlation': np.float64(0.5586212743248736), 'distance history': array([0.92786437, 0.92635581, 0.92486227, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35744719, 0.36184016, 0.36618512, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(4.311479792153265), 'distFC1': np.float64(5.827401750577514)}
# sub 1 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8333837823895734), 'correlation': np.float64(0.5704139535475756), 'distance history': array([0.92529747, 0.91983914, 0.9154177 , ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.33767279, 0.38295794, 0.42019691, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(33.48125040412321), 'distFC1': np.float64(3425441.449600515)}
# sub 2 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8566482985418233), 'correlation': np.float64(0.6262327376416457), 'distance history': array([0.92278903, 0.92047901, 0.91823213, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36508626, 0.37591903, 0.38644826, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9210938533657197), 'distFC1': np.float64(1.9281582170607563)}
# sub 2 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8533477358964929), 'correlation': np.float64(0.6384909431782652), 'distance history': array([0.92576668, 0.92310231, 0.92053591, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36866451, 0.38207261, 0.39496294, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.802109201921825), 'distFC1': np.float64(1.0556546880737234)}
# sub 3 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8276993826764132), 'correlation': np.float64(0.5848023429842897), 'distance history': array([0.91044425, 0.90871999, 0.90701273, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38546301, 0.38984455, 0.39416981, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.1655246765003022), 'distFC1': np.float64(1.5219532931546118)}
# sub 3 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.
, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9009062478137986), 'distFC1': np.float64(1.1208809669201378)}
# sub 43 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8453106691555373), 'correlation': np.float64(0.5967877968334283), 'distance history': array([0.91617951, 0.91457429, 0.91298363, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.38662318, 0.39113565, 0.39560103, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.6383079117399595), 'distFC1': np.float64(2.100231618424431)}
# sub 43 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8480657149841422), 'correlation': np.float64(0.6142142668587927), 'distance history': array([0.91984558, 0.91737489, 0.91498647, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36463587, 0.37647758, 0.38790833, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(5.864458519739335), 'distFC1': np.float64(21.00523847788365)}
# sub 44 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8453410976708291), 'correlation': np.float64(0.5782933251065336), 'distance history': array([0.92327678, 0.9216824 , 0.92010202, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.36788341, 0.37213539, 0.37634177, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(2.210704960887777), 'distFC1': np.float64(3.2001721997668326)}
# sub 44 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8741409167439043), 'correlation': np.float64(0.5471718146617786), 'distance history': array([0.94405317, 0.94248638, 0.94093804, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.31929384, 0.32434142, 0.3293239 , ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.3757692441741862), 'distFC1': np.float64(1.9502767419312124)}
# sub 45 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8547931236686227), 'correlation': np.float64(0.5876041461690404), 'distance history': array([0.93132534, 0.92963897, 0.92797104, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.3523561 , 0.35761894, 0.36281428, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(1.438774981851082), 'distFC1': np.float64(1.7983883644283527)}
# sub 45 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8495675143264443), 'correlation': np.float64(0.6400281333800768), 'distance history': array([0.91994585, 0.91763701, 0.91538799, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.37743216, 0.38745371, 0.39720022, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.8548727664975542), 'distFC1': np.float64(1.1282774193624632)}
# sub 46 ; cond 0 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8694978801110258), 'correlation': np.float64(0.5819514492421262), 'distance history': array([0.92833045, 0.92656779, 0.92483266, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.35671668, 0.36373155, 0.37062334, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9443040993469745), 'distFC1': np.float64(1.3185246682103506)}
# sub 46 ; cond 1 : {'n_tau': 2, 'iterations': 102, 'distance': np.float64(0.8959681344531445), 'correlation': np.float64(0.49270961217261666), 'distance history': array([0.94520069, 0.94373776, 0.94229575, ..., 0.        , 0.        ,
#        0.        ]), 'correlation history': array([0.30901393, 0.31454321, 0.31999032, ..., 0.        , 0.        ,
#        0.        ]), 'distFC0': np.float64(0.9092811737812254), 'distFC1': np.float64(1.1933764020790576)}

# %%
plt.imshow(mask_EC1)

# %% [markdown]
# ## Check goodness of fit :

# %%
mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
n_cond=2

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

# model error #err_mod

err_mod_tmp = dict()
err_mod_tmp['sum EC'] = err_mod.flatten()
err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

err_mod_df = pd.DataFrame(err_mod_tmp)

plt.figure()
sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model error',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_fit_error.eps', format='eps')


# Pearson corr #fit_mod

fit_mod_tmp = dict()
fit_mod_tmp['sum EC'] = fit_mod.flatten()
fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

fit_mod_df = pd.DataFrame(fit_mod_tmp)

plt.figure()
sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
plt.axis(ymin=0)

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Condition',fontsize=16)
plt.ylabel('Model goodness of fit',fontsize=16)

plt.tight_layout()
plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')


# Example EC

plt.figure(figsize=(5,4))
#plt.imshow(np.maximum(J_mod[18,1,:,:],0), cmap='Reds')
plt.imshow(J_mod[18,1,:,:], cmap='Reds')
plt.colorbar()
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.xlabel('Target ROI index', fontsize=16)
plt.ylabel('Source ROI index', fontsize=16)
plt.tight_layout()
plt.savefig(res_dir+'example_EC.eps', format='eps')
# Out:
# /tmp/ipykernel_5836/4027539692.py:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5836/4027539692.py:16: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5836/4027539692.py:39: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
# /tmp/ipykernel_5836/4027539692.py:39: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)

# %% [markdown]
# ## ENTROPY CALCULATION

# %%
# transpose to Saclay's framework
EPR = np.zeros([n_sub,n_cond])
Q_indiv = np.zeros([n_sub,n_cond,N,N])

for i_sub in range(n_sub):
    for i_cond in range(n_cond):

        try:
            B = np.copy(-J_mod[i_sub,i_cond,:,:].T)
            D = np.copy(0.5 * Sigma_mod[i_sub,i_cond,:,:])
            S = np.copy(FC0_mod[i_sub,i_cond,:,:])
            
            Q = np.dot(B, S) - D
            Q_indiv[i_sub,i_cond,:,:] = Q
            
            # sanity check
            if True:
                print('should be close to zero:', np.abs(np.dot(B,S) + np.dot(S,B.T) -2*D).max())
            
            # formula from Godreche Luck
            Dinv = np.linalg.pinv(D)
            Sinv = np.linalg.pinv(S)
            
            entropy_prod_rate = -np.trace(np.dot(np.dot(np.dot(Sinv, Q), Dinv), Q))
            EPR[i_sub,i_cond] = entropy_prod_rate

        except:
            print('problem with subject/cond:', i_sub, i_cond)
# Out:
# should be close to zero: 7.993605777301127e-15
# should be close to zero: 2.7533531010703882e-14
# should be close to zero: 5.773159728050814e-15
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 1.509903313490213e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 6.217248937900877e-15
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 7.105427357601002e-15
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 3.907985046680551e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 1.1102230246251565e-14
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 8.108097526715596e-15
# should be close to zero: 0.0
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 2.1316282072803006e-14
# should be close to zero: 1.7763568394002505e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 3.019806626980426e-14
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 4.085620730620576e-14
# should be close to zero: 7.993605777301127e-15
# should be close to zero: 1.4210854715202004e-14
# should be close to zero: 5.995204332975845e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 1.5987211554602254e-14
# should be close to zero: 5.551115123125783e-15
# should be close to zero: 2.4868995751603507e-14
# should be close to zero: 7.327471962526033e-15
# should be close to zero: 1.021405182655144e-14
# should be close to zero: 1.0658141036401503e-14
# should be close to zero: 3.730349362740526e-14
# should be close to zero: 5.551115123125783e-15
# should be close to zero: 2.6645352591003757e-14
# should be close to zero: 2.220446049250313e-14
# should be close to zero: 3.907985046680551e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 1.9539925233402755e-14
# should be close to zero: 6.8833827526759706e-15
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 1.2434497875801753e-14
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 8.659739592076221e-15
# should be close to zero: 2.220446049250313e-14
# should be close to zero: 1.3766765505351941e-14
# should be close to zero: 2.220446049250313e-14
# should be close to zero: 2.3092638912203256e-14
# should be close to zero: 8.881784197001252e-15
# should be close to zero: 2.398081733190338e-14
# should be close to zero: 1.8207657603852567e-14
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 4.884981308350689e-15
# should be close to zero: 2.930988785010413e-14
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 1.554312234475219e-14
# should be close to zero: 1.199040866595169e-14
# should be close to zero: 2.930988785010413e-14
# should be close to zero: 1.7763568394002505e-14
# should be close to zero: 2.042810365310288e-14
# should be close to zero: 9.769962616701378e-15
# should be close to zero: 1.1546319456101628e-14
# should be close to zero: 7.549516567451064e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 9.325873406851315e-15
# should be close to zero: 7.105427357601002e-15
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 1.687538997430238e-14
# should be close to zero: 6.439293542825908e-15
# should be close to zero: 1.3322676295501878e-14
# should be close to zero: 8.43769498715119e-15
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 6.661338147750939e-15
# should be close to zero: 1.2878587085651816e-14
# should be close to zero: 1.4654943925052066e-14
# should be close to zero: 1.1546319456101628e-14

# %%
#%% plots

matplotlib.rc('font', size=12) 
matplotlib.rc('xtick', labelsize=12)
matplotlib.rc('ytick', labelsize=12)

cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]]
cols2 = [[0.7,0.7,1],[0.6,0.6,1],[0.5,0.5,1],[0.4,0.4,1]]

EPR_tmp = dict()
EPR_tmp['sleep stage'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()
EPR_tmp['EPR'] = EPR.flatten()

EPR_df = pd.DataFrame(EPR_tmp)


# real data

plt.figure()
ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
sb.swarmplot(data=EPR_df, x='sleep stage', y='EPR', color=[0.7,0.7,0.7])
plt.axis(ymin=0, ymax=5)

plt.xlabel('Condition', fontsize=12)
plt.ylabel('Entropy production rate', fontsize=12)

plt.savefig(res_dir+'entropy_prod_rate.eps', format='eps')
# Out:
# /tmp/ipykernel_5836/2923277758.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)
# /tmp/ipykernel_5836/2923277758.py:20: UserWarning: The palette list has more values (4) than needed (2), which may not be intended.
#   ax = sb.violinplot(data=EPR_df, x='sleep stage', y='EPR', palette=cols)

# %%
EPR_df
# Out:
#    sleep stage       EPR
# 0          CTR  0.682708
# 1          SCZ  1.319306
# 2          CTR  0.490407
# 3          SCZ  2.238933
# 4          CTR  0.991270
# ..         ...       ...
# 89         SCZ  0.439259
# 90         CTR  0.485846
# 91         SCZ  0.597489
# 92         CTR  0.763343
# 93         SCZ  0.745759
#
# [94 rows x 2 columns]

# %% [markdown]
# Verify that the two groups are
# ## Statistically Different

# %% [markdown]
# 3. Check if the two groups are statistically different: WELCH TEST

# %%
CTR = EPR[:,0]
SCZ = EPR[:,1]
stat_t, p_t = stats.ttest_ind(CTR, SCZ, equal_var=False)

print(f"Welch's t-test statistic: {stat_t:.3f}, p-value: {p_t:.3f}")

if p_t < 0.05:
    print("The difference between groups is statistically significant.")
else:
    print("No significant difference between groups.")
# Out:
# Welch's t-test statistic: -3.431, p-value: 0.001
# The difference between groups is statistically significant.
