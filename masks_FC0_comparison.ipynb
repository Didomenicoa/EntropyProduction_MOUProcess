# %%
# numpy and scipy
import numpy as np
import scipy.linalg as spl
import scipy.signal as spsg
import scipy.io as sio
import scipy.stats as stats

# MOU model
from test_MOU_largenet import MOUv2

# classification scikit-learn
import sklearn.linear_model as skllm
import sklearn.preprocessing as skppr
import sklearn.pipeline as skppl
import sklearn.neighbors as sklnn

# plotting
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sb
import pandas as pd

#statistical tests
import scipy.stats as stats

#importing ENIGMA
from enigmatoolbox.datasets import load_sc_as_one
from nilearn import plotting

# %%
data_dir = './' # data repo
res_dir = './' # results
graph_format = 'png' # graph formatting

conds = ['CTR', 'SCZ'] #conditions
n_cond = len(conds) # number of conditions

# 68 is the number of brain regions
N = 68 # size of network for DK-68

# %%
sc_sctx, sc_sctx_labels = load_sc_as_one()

# Plot subcortico-cortical connectivity matrices
#sc_plot = plotting.plot_matrix(sc_sctx, figure=(9, 9), labels=sc_sctx_labels, vmax=10, vmin=0, cmap='Blues')

SC = sc_sctx[0:68,0:68]

# %%
#NB: ./ = prendi il path
ts_ctr = sio.loadmat('./ts_ctr.mat')['ts_ctr'] 
ts_ctr=ts_ctr[0:68,:,20:68]
ts_scz = sio.loadmat('./ts_scz.mat')['ts_scz']
ts_scz=ts_scz[0:68]
ts_all = np.stack((ts_ctr, ts_scz), axis=-1)

ts_all.shape
#68 = brain regions
#48 = patients
#152 = time 
#2 = ctr, scz = conditions
# Out:
# (68, 152, 48, 2)

# %%
# BOLD broadband filtering
n_order = 2
TR = 2.0 # in seconds

Nyquist_freq = 0.5 / TR # Nyquist frequency
low_f = 0.001 / Nyquist_freq # lower cutoff for bandpass filter
high_f = 0.01  / Nyquist_freq # upper cutoff for bandpass filter
b,a = spsg.iirfilter(n_order,[low_f,high_f],btype='bandpass',ftype='butter')

# lags (in TR): 0 and 1
v_lag = np.arange(2,dtype=float)
n_lag = v_lag.size

# calc example FC for single subj
ts = sio.loadmat(data_dir+'ts_ctr.mat')['ts_ctr']
#ts = sio.loadmat('./ts_ctr.mat')['ts_ctr']
ts=ts[:, :,1]
filt_ts = spsg.filtfilt(b,a,ts,axis=1)
FC0 = np.tensordot(filt_ts[:,:-1], filt_ts[:,:-1], axes=(1,1)) / 150
FC1 = np.tensordot(filt_ts[:,:-1], filt_ts[:,1:], axes=(1,1)) / 150

# %% [markdown]
# # Masks

# %%
import numpy as np
import scipy.signal as spsg
from scipy import stats
from scipy.linalg import solve_lyapunov as spl

# Assuming MOUv2 is a defined class elsewhere
# from your_library import MOUv2 

# Data and model parameters
subjects = np.arange(1, 48)
n_sub = len(subjects)
N = 68

mask_Sigma = np.eye(N, dtype=bool)
conds = ['CTR', 'SCZ']
n_cond = len(conds)

# Arrays to store results
var_BOLD = np.zeros([n_sub, n_cond, N])
FC0p_list = [50, 60, 60, 70, 70]
FC1p_list = [40, 40, 50, 50, 60]
n_p = len(FC0p_list)

J_mods = {i_p: np.zeros([n_sub, n_cond, N, N]) for i_p in range(n_p)}
Sigma_mods = {i_p: np.zeros([n_sub, n_cond, N, N]) for i_p in range(n_p)}
FC0_mods = {i_p: np.zeros([n_sub, n_cond, N, N]) for i_p in range(n_p)}
err_mods = {i_p: np.zeros([n_sub, n_cond]) for i_p in range(n_p)}
fit_mods = {i_p: np.zeros([n_sub, n_cond]) for i_p in range(n_p)}

# Filter design
n_order = 3
TR = 2  # in seconds
Nyquist_freq = 0.5 / TR
low_f = 0.001 / Nyquist_freq
high_f = 0.01 / Nyquist_freq
b, a = spsg.iirfilter(n_order, [low_f, high_f], btype='bandpass', ftype='butter')

# Function for empirical correlations MASKS
def mask(FC0p, FC1p, ts_all, i_sub, i_cond):
    ts3 = ts_all[0:68, :, i_sub, i_cond]
    filt_ts = spsg.filtfilt(b, a, ts3, axis=1)
    ts = stats.zscore(filt_ts, axis=1)
    
    # Store empirical BOLD variance
    var_BOLD[i_sub, i_cond, :] = ts.var(axis=1)
    
    FC0 = np.tensordot(ts[:, :-1], ts[:, :-1], axes=(1, 1)) / ts.shape[1]
    FC1 = np.tensordot(ts[:, :-1], ts[:, 1:], axes=(1, 1)) / ts.shape[1]
    FC0N = np.abs(FC0) / np.max(np.abs(FC0))
    FC1N = np.abs(FC1) / np.max(np.abs(FC1))
    
    lim_FC0 = np.percentile(FC0N, FC0p)
    lim_FC1 = np.percentile(FC1N, FC1p)

    mask_EC1 = FC0N > lim_FC0
    np.fill_diagonal(mask_EC1, True)
    
    mask_EC2 = FC1N > lim_FC1
    np.fill_diagonal(mask_EC2, False)
    
    return mask_EC1

# Loop over subjects, conditions, and parameters
for i_sub in range(n_sub):
    print(f"Sub {i_sub+1}/{n_sub}")
    for i_cond in range(n_cond):
        for i_p in range(n_p):
            mask_EC = mask(FC0p_list[i_p], FC1p_list[i_p], ts_all, i_sub, i_cond)
            
            # Invert model
            mou_est = MOUv2()
            fit_res = mou_est.fit(
                ts_all[:, :, i_sub, i_cond].T,
                mask_C=mask_EC,
                mask_Sigma=mask_Sigma,
                algo_version='true',
                min_iter=100,
                epsilon_C=0.005,
                epsilon_Sigma=0.005,
            )
            
            # Store results
            J_mods[i_p][i_sub, i_cond, :, :] = fit_res.J
            Sigma_mods[i_p][i_sub, i_cond, :, :] = fit_res.Sigma
            FC0_mods[i_p][i_sub, i_cond, :, :] = spl(
                J_mods[i_p][i_sub, i_cond, :, :].T,
                -Sigma_mods[i_p][i_sub, i_cond, :, :]
            )
            err_mods[i_p][i_sub, i_cond] = fit_res.d_fit['distance']
            fit_mods[i_p][i_sub, i_cond] = fit_res.d_fit['correlation']
# Out:
# Sub 1/47
# Sub 2/47
# Sub 3/47
# Sub 4/47
# Sub 5/47
# Sub 6/47
# Sub 7/47
# Sub 8/47
# Sub 9/47
# Sub 10/47
# Sub 11/47
# Sub 12/47
# Sub 13/47
# Sub 14/47
# Sub 15/47
# Sub 16/47
# Sub 17/47
# Sub 18/47
# Sub 19/47
# Sub 20/47
# Sub 21/47
# Sub 22/47
# Sub 23/47
# Sub 24/47
# Sub 25/47
# Sub 26/47
# Sub 27/47
# Sub 28/47
# Sub 29/47
# Sub 30/47
# Sub 31/47
# Sub 32/47
# Sub 33/47
# Sub 34/47
# Sub 35/47
# Sub 36/47
# Sub 37/47
# Sub 38/47
# Sub 39/47
# Sub 40/47
# Sub 41/47
# Sub 42/47
# Sub 43/47
# Sub 44/47
# Sub 45/47
# Sub 46/47
# Sub 47/47

# %%
#to improve graphs visibility
import warnings
warnings.filterwarnings("ignore")# numpy and scipy

#plot graphs
def fit_goodness(err_mod, fit_mod):
    mask_diag = np.eye(N, dtype=bool) # mask for diagonal elements
    n_cond=2

    cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]] # colors

    # model error

    err_mod_tmp = dict()
    err_mod_tmp['sum EC'] = err_mod.flatten()
    err_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
    err_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

    err_mod_df = pd.DataFrame(err_mod_tmp)

    plt.figure(figsize=(16,6))
    plt.subplot(1, 2, 1)
    sb.violinplot(data=err_mod_df, x='cond', y='sum EC', palette=cols)
    sb.swarmplot(data=err_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
    plt.axis(ymin=0)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel('Condition',fontsize=16)
    plt.ylabel('Model error',fontsize=16)
    plt.title(f'FC0: {FC0p_list[i_p]}, FC1: {FC1p_list[i_p]}')

    plt.tight_layout()
    #plt.savefig(res_dir+'model_fit_error.eps', format='eps')


    # Pearson corr

    fit_mod_tmp = dict()
    fit_mod_tmp['sum EC'] = fit_mod.flatten()
    fit_mod_tmp['sub'] = np.repeat(np.arange(n_sub), n_cond).flatten()
    fit_mod_tmp['cond'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()

    fit_mod_df = pd.DataFrame(fit_mod_tmp)

    plt.subplot(1, 2, 2)
    sb.violinplot(data=fit_mod_df, x='cond', y='sum EC', palette=cols)
    sb.swarmplot(data=fit_mod_df, x='cond', y='sum EC', color=[0.7,0.7,0.7])
    plt.axis(ymin=0)

    plt.xticks(fontsize=14)
    plt.yticks(fontsize=14)
    plt.xlabel('Condition',fontsize=16)
    plt.ylabel('Model goodness of fit',fontsize=16)
    plt.title(f'FC0: {FC0p_list[i_p]}, FC1: {FC1p_list[i_p]}')

    plt.tight_layout()
    plt.show()
    #plt.savefig(res_dir+'model_goodness_fit.eps', format='eps')

for i_p in range(n_p):
    fit_goodness(err_mods[i_p], fit_mods[i_p])

# %%
# transpose to Saclay's framework
EPR = {i_p: np.zeros([n_sub, n_cond]) for i_p in range(n_p)}
Q_indiv = {i_p: np.zeros([n_sub, n_cond, N, N]) for i_p in range(n_p)}

for i_sub in range(n_sub):
    for i_cond in range(n_cond):
        for i_p in range(n_p):
            try:
                B = np.copy(-J_mods[i_p][i_sub,i_cond,:,:].T)
                D = np.copy(0.5 * Sigma_mods[i_p][i_sub,i_cond,:,:])
                S = np.copy(FC0_mods[i_p][i_sub,i_cond,:,:])
                
                Q = np.dot(B, S) - D
                Q_indiv[i_p][i_sub,i_cond,:,:] = Q
                
                # sanity check
                if True:
                    print('should be close to zero:', np.abs(np.dot(B,S) + np.dot(S,B.T) -2*D).max())
            
                # formula from Godreche Luck
                Dinv = np.linalg.pinv(D)
                Sinv = np.linalg.pinv(S)
                
                entropy_prod_rate = -np.trace(np.dot(np.dot(np.dot(Sinv, Q), Dinv), Q))
                EPR[i_p][i_sub,i_cond] = entropy_prod_rate

            except:
                print('problem with subject/cond:', i_sub, i_cond)
# Out:
# should be close to zero: 3.6193270602780103e-14
# should be close to zero: 7.460698725481052e-14
# should be close to zero: 7.460698725481052e-14
# should be close to zero: 4.796163466380676e-14
# should be close to zero: 4.796163466380676e-14
# should be close to zero: 8.881784197001252e-14
# should be close to zero: 7.155907810751927e-14
# should be close to zero: 7.155907810751927e-14
# should be close to zero: 1.3500311979441904e-13
# should be close to zero: 1.3500311979441904e-13
# should be close to zero: 7.105427357601002e-14
# should be close to zero: 5.1236792586450974e-14
# should be close to zero: 5.1236792586450974e-14
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 3.979039320256561e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 7.105427357601002e-13
# should be close to zero: 7.105427357601002e-13
# should be close to zero: 9.592326932761353e-14
# should be close to zero: 6.286811349287547e-14
# should be close to zero: 6.286811349287547e-14
# should be close to zero: 1.2872325818105712e-13
# should be close to zero: 1.2872325818105712e-13
# should be close to zero: 7.105427357601002e-14
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 9.514611321037592e-14
# should be close to zero: 9.514611321037592e-14
# should be close to zero: 4.263256414560601e-13
# should be close to zero: 4.263256414560601e-13
# should be close to zero: 4.121147867408581e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 5.115907697472721e-13
# should be close to zero: 5.115907697472721e-13
# should be close to zero: 1.7328152801532326e-13
# should be close to zero: 1.8340190477417195e-13
# should be close to zero: 1.8340190477417195e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 2.0961010704922955e-13
# should be close to zero: 2.0961010704922955e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 7.12351184983806e-14
# should be close to zero: 7.12351184983806e-14
# should be close to zero: 7.460698725481052e-14
# should be close to zero: 7.460698725481052e-14
# should be close to zero: 1.0913492332065289e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 5.626705698591472e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 4.744815651491763e-14
# should be close to zero: 4.744815651491763e-14
# should be close to zero: 1.0942358130705543e-12
# should be close to zero: 6.110667527536862e-13
# should be close to zero: 6.110667527536862e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 3.903333819360588e-14
# should be close to zero: 3.903333819360588e-14
# should be close to zero: 2.2026824808563106e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 2.3447910280083306e-13
# should be close to zero: 2.3447910280083306e-13
# should be close to zero: 1.8425972553304248e-13
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 2.0961010704922955e-13
# should be close to zero: 2.0961010704922955e-13
# should be close to zero: 3.4916497861428586e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 2.0511543852297365e-13
# should be close to zero: 2.0511543852297365e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 3.694822225952521e-13
# should be close to zero: 3.694822225952521e-13
# should be close to zero: 3.9612757518625585e-13
# should be close to zero: 3.9612757518625585e-13
# should be close to zero: 4.263256414560601e-13
# should be close to zero: 1.0800249583553523e-12
# should be close to zero: 1.0800249583553523e-12
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 5.1514348342607263e-14
# should be close to zero: 5.1514348342607263e-14
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.4921397450962104e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 0.0
# should be close to zero: 0.0
# should be close to zero: 0.0
# should be close to zero: 0.0
# should be close to zero: 0.0
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 8.881784197001252e-14
# should be close to zero: 8.881784197001252e-14
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 2.1277424266941125e-13
# should be close to zero: 7.673861546209082e-13
# should be close to zero: 7.673861546209082e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 7.83262343873048e-14
# should be close to zero: 7.83262343873048e-14
# should be close to zero: 1.0302869668521453e-13
# should be close to zero: 1.0302869668521453e-13
# should be close to zero: 1.4233059175694507e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 2.5224267119483557e-13
# should be close to zero: 2.5224267119483557e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 2.7711166694643907e-13
# should be close to zero: 2.7711166694643907e-13
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 7.389644451905042e-13
# should be close to zero: 9.094947017729282e-13
# should be close to zero: 9.094947017729282e-13
# should be close to zero: 3.808509063674137e-12
# should be close to zero: 3.808509063674137e-12
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.946776073680212e-13
# should be close to zero: 1.946776073680212e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 9.592326932761353e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 3.907985046680551e-14
# should be close to zero: 3.907985046680551e-14
# should be close to zero: 7.105427357601002e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 5.3290705182007514e-14
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 8.797129691373584e-14
# should be close to zero: 8.797129691373584e-14
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 2.6290081223123707e-13
# should be close to zero: 2.6290081223123707e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 3.694822225952521e-13
# should be close to zero: 3.694822225952521e-13
# should be close to zero: 1.5420997812043424e-13
# should be close to zero: 1.5420997812043424e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 7.815970093361102e-14
# should be close to zero: 7.815970093361102e-14
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 2.8421709430404007e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 2.128297538206425e-13
# should be close to zero: 2.128297538206425e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.3145040611561853e-13
# should be close to zero: 1.3145040611561853e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 8.942846463355636e-14
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 9.637169534615353e-14
# should be close to zero: 9.637169534615353e-14
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 1.9184653865522705e-13
# should be close to zero: 1.9184653865522705e-13
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.0302869668521453e-13
# should be close to zero: 1.0302869668521453e-13
# should be close to zero: 3.979039320256561e-13
# should be close to zero: 1.8107737531636303e-13
# should be close to zero: 1.8107737531636303e-13
# should be close to zero: 4.121147867408581e-13
# should be close to zero: 4.121147867408581e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.4921397450962104e-13
# should be close to zero: 1.4921397450962104e-13
# should be close to zero: 3.694822225952521e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 2.4158453015843406e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 2.2026824808563106e-13
# should be close to zero: 2.2026824808563106e-13
# should be close to zero: 1.328520626842078e-13
# should be close to zero: 1.328520626842078e-13
# should be close to zero: 1.4921397450962104e-13
# should be close to zero: 9.335587858316785e-14
# should be close to zero: 9.335587858316785e-14
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.5987211554602254e-13
# should be close to zero: 1.5987211554602254e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 6.394884621840902e-14
# should be close to zero: 6.394884621840902e-14
# should be close to zero: 1.3061773884714967e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 2.3803181647963356e-13
# should be close to zero: 9.592326932761353e-14
# should be close to zero: 9.592326932761353e-14
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 4.475586568020162e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 4.973799150320701e-14
# should be close to zero: 4.973799150320701e-14
# should be close to zero: 9.526754385369429e-14
# should be close to zero: 1.0835776720341528e-13
# should be close to zero: 1.0835776720341528e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 2.1316282072803006e-13
# should be close to zero: 1.4921397450962104e-13
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.2789769243681803e-13
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.0197398481182063e-13
# should be close to zero: 1.0197398481182063e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 5.593442375939617e-14
# should be close to zero: 5.593442375939617e-14
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 6.572520305780927e-14
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 1.1013412404281553e-13
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 1.0600548216999073e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 7.958078640513122e-13
# should be close to zero: 2.3874235921539366e-12
# should be close to zero: 2.3874235921539366e-12
# should be close to zero: 1.7053025658242404e-12
# should be close to zero: 1.7053025658242404e-12
# should be close to zero: 1.3500311979441904e-13
# should be close to zero: 6.039613253960852e-14
# should be close to zero: 6.039613253960852e-14
# should be close to zero: 1.2434497875801753e-13
# should be close to zero: 1.2434497875801753e-13
# should be close to zero: 1.7366490190351414e-13
# should be close to zero: 3.979039320256561e-13
# should be close to zero: 3.979039320256561e-13
# should be close to zero: 3.410605131648481e-13
# should be close to zero: 3.410605131648481e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 1.3100631690576847e-13
# should be close to zero: 1.3100631690576847e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 5.115907697472721e-13
# should be close to zero: 7.673861546209082e-13
# should be close to zero: 7.673861546209082e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 7.815970093361102e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 8.602753925890383e-14
# should be close to zero: 8.602753925890383e-14
# should be close to zero: 1.3855583347321954e-13
# should be close to zero: 9.4840801878604e-14
# should be close to zero: 9.4840801878604e-14
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 7.283063041541027e-14
# should be close to zero: 7.283063041541027e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 1.2434497875801753e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 1.0658141036401503e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 2.2737367544323206e-13
# should be close to zero: 3.481659405224491e-13
# should be close to zero: 3.481659405224491e-13
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 4.547473508864641e-13
# should be close to zero: 9.094947017729282e-13
# should be close to zero: 9.094947017729282e-13
# should be close to zero: 6.536993168992922e-13
# should be close to zero: 6.536993168992922e-13
# should be close to zero: 8.171241461241152e-14
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 6.750155989720952e-14
# should be close to zero: 8.171241461241152e-14
# should be close to zero: 8.171241461241152e-14
# should be close to zero: 2.87214696470528e-13
# should be close to zero: 1.6614487563515468e-13
# should be close to zero: 1.6614487563515468e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 9.237055564881302e-14
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 2.7000623958883807e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.1368683772161603e-13
# should be close to zero: 1.1723955140041653e-13
# should be close to zero: 8.14071032806396e-14
# should be close to zero: 8.14071032806396e-14
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 1.7763568394002505e-13
# should be close to zero: 1.8474111129762605e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 1.078026556911027e-13
# should be close to zero: 1.078026556911027e-13
# should be close to zero: 2.5579538487363607e-13
# should be close to zero: 9.521272659185342e-13
# should be close to zero: 9.521272659185342e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 3.268496584496461e-13
# should be close to zero: 8.526512829121202e-14
# should be close to zero: 7.105427357601002e-14
# should be close to zero: 7.105427357601002e-14
# should be close to zero: 5.931366509059899e-14
# should be close to zero: 5.931366509059899e-14
# should be close to zero: 2.984279490192421e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.5631940186722204e-13
# should be close to zero: 1.9895196601282805e-13
# should be close to zero: 1.0652589921278377e-13
# should be close to zero: 1.0652589921278377e-13
# should be close to zero: 1.3500311979441904e-13
# should be close to zero: 1.3500311979441904e-13
# should be close to zero: 1.3642420526593924e-12
# should be close to zero: 2.5011104298755527e-12
# should be close to zero: 2.5011104298755527e-12
# should be close to zero: 3.410605131648481e-12
# should be close to zero: 3.410605131648481e-12
# should be close to zero: 1.7053025658242404e-13
# should be close to zero: 1.5210055437364645e-13
# should be close to zero: 1.5210055437364645e-13
# should be close to zero: 3.836930773104541e-13
# should be close to zero: 3.836930773104541e-13
# should be close to zero: 1.6342482922482304e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 3.126388037344441e-13
# should be close to zero: 2.0605739337042905e-13
# should be close to zero: 2.0605739337042905e-13
# should be close to zero: 4.973799150320701e-14
# should be close to zero: 4.263256414560601e-14
# should be close to zero: 4.263256414560601e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 5.684341886080802e-14
# should be close to zero: 1.2079226507921703e-13
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 9.947598300641403e-14
# should be close to zero: 1.4210854715202004e-13
# should be close to zero: 1.4210854715202004e-13

# %%
#%% plots
def EPR_plot(EPR):
    matplotlib.rc('font', size=12) 
    matplotlib.rc('xtick', labelsize=12)
    matplotlib.rc('ytick', labelsize=12)

    cols = [[0.3,0.3,1],[0.2,0.2,0.8],[0.1,0.1,0.6],[0,0,0.4]]
    cols2 = [[0.7,0.7,1],[0.6,0.6,1],[0.5,0.5,1],[0.4,0.4,1]]

    EPR_tmp = dict()
    EPR_tmp['conditions'] = np.repeat(np.array(conds, dtype=str).reshape([-1,n_cond]), n_sub, axis=0).flatten()
    EPR_tmp['EPR'] = EPR.flatten()

    EPR_df = pd.DataFrame(EPR_tmp)


    # real data

    plt.figure()
    ax = sb.violinplot(data=EPR_df, x='conditions', y='EPR', palette=cols)
    sb.swarmplot(data=EPR_df, x='conditions', y='EPR', color=[0.7,0.7,0.7])
    plt.axis(ymin=0, ymax=5)

    plt.xlabel('Condition', fontsize=12)
    plt.ylabel('Entropy production rate', fontsize=12)
    plt.title(f'FC0: {FC0p_list[i_p]}, FC1: {FC1p_list[i_p]}')
    plt.show()

for i_p in range(n_p):
    EPR_plot(EPR[i_p])
#plt.savefig(res_dir+'entropy_prod_rate.eps', format='eps')

# %%
#Check if they are statistically independent
for i_p in range(n_p):
    CTR = EPR[i_p][:,0]
    SCZ = EPR[i_p][:,1]
    stat_t, p_t = stats.ttest_ind(CTR, SCZ, equal_var=False)

    print(f"Welch's t-test statistic: {stat_t:.3f}, p-value: {p_t:.3f}")

    if p_t < 0.05:
        print("The difference between groups is statistically significant.")
    else:
        print("No significant difference between groups.")
# Out:
# Welch's t-test statistic: -2.882, p-value: 0.005
# The difference between groups is statistically significant.
# Welch's t-test statistic: -2.843, p-value: 0.006
# The difference between groups is statistically significant.
# Welch's t-test statistic: -2.843, p-value: 0.006
# The difference between groups is statistically significant.
# Welch's t-test statistic: -2.780, p-value: 0.007
# The difference between groups is statistically significant.
# Welch's t-test statistic: -2.780, p-value: 0.007
# The difference between groups is statistically significant.
